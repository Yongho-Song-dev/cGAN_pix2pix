# %% [markdown]
# ## Segmentation map으로 도로 이미지 만들기
# Pix2Pix 논문에서 제시한 실험 중에 도로의 레이블 정보를 활용해 이미지를 생성해낸 실험이 있습니다.
# 이번 프로젝트에선 해당 논문에서 사용한 데이터셋을 Pix2Pix를 학습시켜보겠습니다.

# %% [markdown]
# 1. Data augementation을 부족한 데이터의 수 증가
#
#
# 2. Generator로 U-Net Generator 구조를 사용
#
#
# 3. 학습된 Generator와 테스트 이미지를 사용해 테스트를 진행해 보겠습니다.
#
#
# 4. 3에서 Generator로 생성된 이미지를 segmentation map, Generator 생성 이미지, 실제 사진으로 시각화해서 잘되었는지 살펴 봅시다.
#
#
# 5. 다양한 epoch 학습을 진행해 epoch가 이미지에 생성에 미치는 영향을 확인해 봅시다.

# %%
import os  # 데이터 로드
from tensorflow import data

# 데이터 코드 조작
import numpy as np 
import tensorflow as tf  

# 이미지 처리
import cv2    
import matplotlib.pyplot as plt

# data agumentation
from tensorflow import image
from tensorflow.keras.preprocessing.image import random_rotation

print("데이터 준비 모듈 import")



from tensorflow.keras import layers, Input, Model

print("Generator, Discriminator 모듈 import")
# Out:
# 데이터 준비 모듈 import
# Generator, Discriminator 모듈 import

# %% [markdown]
# ## 1. 데이터 준비
# - 데이터 로드
#
# - 불러온 이미지가 실제 이미지와, segmentation map이 붙어 있으므로 이 둘을 분리해서 사용합니다.
#
# - Data augmentation 적용 :
# &nbsp; train 데이터가 1000개로 적은 수이기에 data augmentation을 통해 늘려주겠습니다.

# %%
train_path = os.getenv('HOME')+'/aiffel/conditional_generation/cityscapes/train/'
val_path = os.getenv('HOME')+'/aiffel/conditional_generation/cityscapes/val/'

print("number of train examples :", len(os.listdir(train_path)))
# Out:
# number of train examples : 1000

# %% [markdown]
# 논문에서 알 수 있듯이 train 데이터에는 1000개의 이미지가 있음을 확인할 수 있습니다.
#
# 이제 train 이미지가 어떻게 생겼는지 학습용 데이터셋에서 임의로 6장을 선택하여 시각화합니다.

# %%
plt.figure(figsize=(20,15))
for i in range(1, 7):
    f = train_path + os.listdir(train_path)[np.random.randint(1000)]
    img = cv2.imread(f, cv2.IMREAD_COLOR)
    plt.subplot(3,2,i)
    plt.imshow(img)

# %% [markdown]
# 하나의 이미지에 도로 segmentation map과 실제 도로 이미지가 함께 포함되어 있음을 확인할 수 있습니다.
#
# 이미지를 하나 열어 아래와 같이 크기를 확인해 보겠습니다.

# %%
f = train_path + os.listdir(train_path)[0]
img = cv2.imread(f, cv2.IMREAD_COLOR)
print(img.shape)
# Out:
# (256, 512, 3)

# %% [markdown]
# (256, 512, 3)으로 확인되었습니다. 모델 학습에 사용할 데이터를 (256, 256, 3) 크기의 2개 이미지로 분할하여 사용하면 될 것 같네요.
#
# 아래 코드로 이미지를 나누어 봅시다.

# %%
def normalize(x):
    x = tf.cast(x, tf.float32)
    return (x/127.5) - 1

def denormalize(x):
    x = (x+1)*127.5
    x = x.numpy()
    return x.astype(np.uint8)

def load_img(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_image(img, 3)
    
    w = tf.shape(img)[1] // 2
    road = img[:, :w, :] 
    road = tf.cast(road, tf.float32)
    segment_map = img[:, w:, :] 
    segment_map = tf.cast(segment_map, tf.float32)
    return  normalize(segment_map), normalize(road)

f = train_path + os.listdir(train_path)[1]
segment_map , road  = load_img(f)

plt.figure(figsize=(10,7))
plt.subplot(1,2,1); plt.imshow(denormalize(segment_map))
plt.subplot(1,2,2); plt.imshow(denormalize(road))

# %% [markdown]
# 위와 같이 두 개 이미지로 나누었습니다. 첫 번째 segment_map를 다음 단계에서 구성할 Pix2Pix 모델에 입력하여 두 번째 그림과 같은 실제 이미지를 생성하는 것이 이번 단계의 목표입니다.
#
# 앞서 살펴봤듯이 학습에 사용할 수 있는 데이터의 수는 1000개뿐입니다. 학습에 사용하는 데이터의 다양성을 높이기 위해 아래 코드와 같이 여러 augmentation 방법을 적용해 보겠습니다.

# %%
@tf.function() # 빠른 텐서플로 연산을 위해 @tf.function()을 사용합니다. 
def apply_augmentation(segment_map, road):
    stacked = tf.concat([segment_map, road], axis=-1)
    
    _pad = tf.constant([[30,30],[30,30],[0,0]])
    _pad2 = tf.constant([[52,52],[52,52],[0,0]])
    if tf.random.uniform(()) < .5:
        padded = tf.pad(stacked, _pad, "REFLECT")
    else:
        padded = tf.pad(stacked, _pad, "CONSTANT", constant_values=1.)

    if tf.random.uniform(()) < .5:  # 50% 확률로 이미지 중앙을 기준으로 80% 확대
        padded = image.central_crop(padded, central_fraction=0.8)
        
        # (256, 256) 이미지 사이즈를 맞추기 위헤 PADDING 적용 
        # 256의 0.8이 204.8이므로 52의 패딩을 추가해 준다.

        padded = tf.pad(padded, _pad2, "CONSTANT", constant_values=1.) 
        
        
    out = image.random_crop(padded, size=[256, 256, 6])
    
    if tf.random.uniform(()) < .5:     # 50% 확률로 밝기 조절
        out = image.adjust_brightness(out, 0.35)
    
    out = image.random_flip_left_right(out)
    out = image.random_flip_up_down(out)
    
    if tf.random.uniform(()) < .5:
        degree = tf.random.uniform([], minval=1, maxval=4, dtype=tf.int32)
        out = image.rot90(out, k=degree)
    
    return out[...,:3], out[...,3:]

# %% [markdown]
# 위와 같이 구성한 함수를 데이터에 적용해 시각화 해봅시다.

# %%
plt.figure(figsize=(15,13))
img_n = 1
for i in range(1, 13, 2):
    augmented_segment, augmented_road = apply_augmentation(segment_map, road)
    
    plt.subplot(3,4,i)
    plt.imshow(denormalize(augmented_segment)); plt.title(f"Image {img_n}")
    plt.subplot(3,4,i+1); 
    plt.imshow(denormalize(augmented_road)); plt.title(f"Image {img_n}")
    img_n += 1

# %% [markdown]
# 위의 보이는 것처럼 agumentation을 통해 매우 다양한 이미지가 생성됩니다. 여기서 사용한 augmentation 방법 외에 더 많은 방법을 활용한다면 더욱더 다양한 데이터셋을 만들어 좋은 일반화 결과를 기대해 볼 수도 있을것 같습니다.
#
# 마지막으로 위 과정들을 학습 데이터에 적용하며, 잘 적용되었는지 하나의 이미지만 시각화하여 확인해 보겠습니다.

# %%
from tensorflow import data

def get_train(img_path):
    segment_map, road = load_img(img_path)
    segment_map, road = apply_augmentation(segment_map, road)
    return segment_map, road

train_images = data.Dataset.list_files(train_path + "*.jpg")
train_images = train_images.map(get_train).shuffle(100).batch(4)

sample = train_images.take(1)
sample = list(sample.as_numpy_iterator())
segment_map, road = (sample[0][0]+1)*127.5, (sample[0][1]+1)*127.5

plt.figure(figsize=(10,5))
plt.subplot(1,2,1); plt.imshow(segment_map[0].astype(np.uint8))
plt.subplot(1,2,2); plt.imshow(road[0].astype(np.uint8))

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Generator 구성 [U-Net]
#
# 이제부터 본격적으로 Pix2Pix 구조를 구현합니다. Tensorflow의 Subclassing 방법을 이용해 모델을 만들겠습니다.
#
# Generator를 단순한 **Encoder-Decoder** 구조로 구성하는 것 보다 Encoder와 Decoder 사이를 skip connection으로 연결한 **U-Net** 구조를 사용한 결과가 훨씬 더 실제 이미지에 가까운 품질을 보입니다.
#
#
# **U-Net** 구조를 간단히 설명하면 Encoder에서 출력된 결과를 Decoder의 입력으로 연결한 기본 구조의 추가적으로 Encoder-Decoder을 skip connection으로 연결한 구조입니다.

# %% [markdown]
# 먼저 Encoder 및 Decoder에 사용되는 기본적인 블록을 구현하겠습니다.

# %%
class EncodeBlock(layers.Layer):
    def __init__(self, n_filters, use_bn=True):
        super(EncodeBlock, self).__init__()
        self.use_bn = use_bn       
        self.conv = layers.Conv2D(n_filters, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.lrelu = layers.LeakyReLU(0.2)

    def call(self, x):
        x = self.conv(x)
        if self.use_bn:
            x = self.batchnorm(x)
        return self.lrelu(x)

    
class DecodeBlock(layers.Layer):
    def __init__(self, f, dropout=True):
        super(DecodeBlock, self).__init__()
        self.dropout = dropout
        self.Transconv = layers.Conv2DTranspose(f, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.relu = layers.ReLU()
        
    def call(self, x):
        x = self.Transconv(x)
        x = self.batchnorm(x)
        if self.dropout:
            x = layers.Dropout(.5)(x)
        return self.relu(x)

# %% [markdown]
# 정의된 블록들을 이용해 한 번에 **U-Net Generator**를 정의해 보겠습니다. 아래 모델의 **__init__()** 메서드에서 Encoder 및 Decoder에서 사용할 모든 블록들을 정의해 놓고, **call()**에서 forward propagation 하도록 합니다.

# %%
class UNetGenerator(Model):
    def __init__(self):
        super(UNetGenerator, self).__init__()
        encode_filters = [64,128,256,512,512,512,512,512]
        decode_filters = [512,512,512,512,256,128,64]
        
        self.encode_blocks = []
        for i, f in enumerate(encode_filters):
            if i == 0:
                self.encode_blocks.append(EncodeBlock(f, use_bn=False))
            else:
                self.encode_blocks.append(EncodeBlock(f))
        
        self.decode_blocks = []
        for i, f in enumerate(decode_filters):
            if i < 3:
                self.decode_blocks.append(DecodeBlock(f))
            else:
                self.decode_blocks.append(DecodeBlock(f, dropout=False))
        
        self.last_conv = layers.Conv2DTranspose(3, 4, 2, "same", use_bias=False)
    
    def call(self, x):
        features = []
        for block in self.encode_blocks:
            x = block(x)
            features.append(x)
        
        features = features[:-1]
                    
        for block, feat in zip(self.decode_blocks, features[::-1]):
            x = block(x)
            x = layers.Concatenate()([x, feat])
        
        x = self.last_conv(x)
        return x
                
    def get_summary(self, input_shape=(256,256,3)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()

# %% [markdown]
# 먼저, **__init__()** 에서 정의된 **encode_blocks** 및 **decode_blocks**가 **call()** 내부에서 차례대로 사용되어 Encoder 및 Decoder 내부 연산을 수행합니다.
# 이때, Encoder와 Decoder 사이의 skip connection을 위해 **features** 라는 리스트를 만들고 Encoder 내에서 사용된 각 블록들의 출력을 차례대로 담았습니다.
#
# 이후 Encoder의 최종 출력이 Decoder의 입력으로 들어가면서 다시 한번 각각의 Decoder 블록들을 통과하는데, **features** 리스트에 있는 각각의 출력들이 Decoder 블록 연산 후 함께 연결되어 다음 블록의 입력으로 사용됩니다.

# %% [markdown]
# ---

# %% [markdown]
# ## 3. Discriminator 구성
#
# Generator만으로 좋은 결과를 도출하기에는 부족합니다. 조금 더 사실적인 이미지를 생성하기 위한 Pix2Pix를 완성시키기 위해서는 Discriminator가 필요합니다.
# 이번 단계에서 Discriminator를 만들어 Pix2Pix 구조를 완성시켜 보겠습니다.

# %% [markdown]
# Pix2Pix 논문에서의 Discriminator의 구조는 2개 입력("in", "unknown")을 받아 연결(CONCAT)한 후, **ENCODE** 블록 5개를 통과합니다.
# 이 중 마지막 블록을 제외한 4개 블록은 논문에서 표기된 "C64-C128-C256-C512"에 해당하며, 마지막은 1(채널)차원 출력을 위한 블록이 추가되었습니다.
#
#
# 최종적으로 출력되는 크기는 (30,30,1)가 되고 출력 크기가 (30, 30)이 되는 이유는 70x70 **PatchGAN**을 사용했기 때문입니다. 최종 (30,30) 출력에서 각 픽셀의 receptive field 크기를 (70,70)으로 맞추기 위해 Discriminator의 출력 크기를 (30,30) 크기로 강제로 맞추는 과정입니다.
#
#
# > 논문에서 말하는 C64의 의미 :
# 64개의 4x4 필터에 stride 2를 적용한 Convolution layer (0.2 slope의 LeakyReLU)

# %% [markdown]
# ### Discriminator 구현하기
# ---
# 마찬가지로 Discriminator에 사용할 기본적인 블록부터 만들겠습니다.

# %%
class DiscBlock(layers.Layer):
    def __init__(self, n_filters, stride=2, custom_pad=False, use_bn=True, act=True):
        super(DiscBlock, self).__init__()
        self.custom_pad = custom_pad
        self.use_bn = use_bn
        self.act = act
        
        if custom_pad:
            self.padding = layers.ZeroPadding2D()
            self.conv = layers.Conv2D(n_filters, 4, stride, "valid", use_bias=False)
        else:
            self.conv = layers.Conv2D(n_filters, 4, stride, "same", use_bias=False)
        
        self.batchnorm = layers.BatchNormalization() if use_bn else None
        self.lrelu = layers.LeakyReLU(0.2) if act else None
        
    def call(self, x):
        if self.custom_pad:
            x = self.padding(x)
            x = self.conv(x)
        else:
            x = self.conv(x)
                
        if self.use_bn:
            x = self.batchnorm(x)
            
        if self.act:
            x = self.lrelu(x)
        return x

# %% [markdown]
# **__init__()** 에서 필요한 만큼 많은 설정을 가능하게끔 했습니다. 필터의 수(**n_filters**), 필터가 순회하는 간격(**stride**), 출력 feature map의 크기를 조절할 수 있도록 하는 패딩 설정(**custom_pad**), BatchNorm의 사용 여부(**use_bn**), 활성화 함수 사용 여부(**act**)가 설정 가능합니다.

# %% [markdown]
# 간단하게 코드를 작성하여 각 출력의 크기가 맞는지 확인해 봅시다.
# - (32,32) 에서 (31, 31) -> (30, 30)으로 갈 수 있는지 테스트해 봅시다.

# %%
inputs = Input((32,32,128))
out = layers.ZeroPadding2D()(inputs)
out = layers.Conv2D(256, 4, 1, "valid", use_bias=False)(out)
out = layers.BatchNormalization()(out)
out = layers.LeakyReLU(0.2)(out)

out = layers.ZeroPadding2D()(out)
out = layers.Conv2D(512, 4, 1, "valid", use_bias=False)(out)
out = layers.BatchNormalization()(out)
out = layers.LeakyReLU(0.2)(out)

out = layers.Dense(1, activation=None)(out)

Model(inputs, out).summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 32, 128)]     0
# _________________________________________________________________
# zero_padding2d (ZeroPadding2 (None, 34, 34, 128)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 31, 31, 256)       524288
# _________________________________________________________________
# batch_normalization (BatchNo (None, 31, 31, 256)       1024
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 31, 31, 256)       0
# _________________________________________________________________
# zero_padding2d_1 (ZeroPaddin (None, 33, 33, 256)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 30, 30, 512)       2097152
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 30, 30, 512)       2048
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 30, 30, 512)       0
# _________________________________________________________________
# dense (Dense)                (None, 30, 30, 1)         513
# =================================================================
# Total params: 2,625,025
# Trainable params: 2,623,489
# Non-trainable params: 1,536
# _________________________________________________________________

# %% [markdown]
# 이러한 코드와 비슷한 설정으로 (width, height) 크기를 1씩 감소시켜서 (30, 30)의 크기로 만들 수 있습니다.
#
# 사용할 기본적인 블록을 만들었으니 이를 이용해 바로 Discriminator를 만들어봅시다.

# %%
class Discriminator(Model):
    def __init__(self):
        super(Discriminator, self).__init__()
        
        self.block1 = layers.Concatenate()
        self.block2 = DiscBlock(n_filters=64, stride=2, custom_pad=False, use_bn=False, act=True)
        self.block3 = DiscBlock(n_filters=128, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block4 = DiscBlock(n_filters=256, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block5 = DiscBlock(n_filters=512, stride=1, custom_pad=True, use_bn=True, act=True)
        self.block6 = DiscBlock(n_filters=1, stride=1, custom_pad=True, use_bn=False, act=False)
        self.sigmoid = layers.Activation("sigmoid")
        
        # filters = [64,128,256,512,1]
        # self.blocks = [layers.Concatenate()]
        # for i, f in enumerate(filters):
        #     self.blocks.append(DiscBlock(
        #         n_filters=f,
        #         strides=2 if i<3 else 1,
        #         custom_pad=False if i<3 else True,
        #         use_bn=False if i==0 and i==4 else True,
        #         act=True if i<4 else False
        #     ))
    
    def call(self, x, y):
        out = self.block1([x, y])
        out = self.block2(out)
        out = self.block3(out)
        out = self.block4(out)
        out = self.block5(out)
        out = self.block6(out)
        return self.sigmoid(out)
    
    def get_summary(self, x_shape=(256,256,3), y_shape=(256,256,3)):
        x, y = Input(x_shape), Input(y_shape) 
        return Model((x, y), self.call(x, y)).summary()

# %% [markdown]
# **__init__()** 내부에서 사용할 블록들을 정의했는데, 이전의 구현들처럼 (위 코드의 주석 처리된 부분과 같이) for loop로 간편하게 블록을 만들 수도 있지만, 쉽게 코드를 읽게끔 총 6개 블록을 각각 따로 만들었습니다.
#
# 첫 번째 블록은 단순한 연결(**concat**)을 수행하며, Discriminator의 최종 출력은 **sigmoid** 활성화를 사용했습니다.

# %%
Discriminator().get_summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 256, 256, 6)  0           input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# disc_block (DiscBlock)          (None, 128, 128, 64) 6144        concatenate[0][0]
# __________________________________________________________________________________________________
# disc_block_1 (DiscBlock)        (None, 64, 64, 128)  131584      disc_block[0][0]
# __________________________________________________________________________________________________
# disc_block_2 (DiscBlock)        (None, 32, 32, 256)  525312      disc_block_1[0][0]
# __________________________________________________________________________________________________
# disc_block_3 (DiscBlock)        (None, 31, 31, 512)  2099200     disc_block_2[0][0]
# __________________________________________________________________________________________________
# disc_block_4 (DiscBlock)        (None, 30, 30, 1)    8192        disc_block_3[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 30, 30, 1)    0           disc_block_4[0][0]
# ==================================================================================================
# Total params: 2,770,432
# Trainable params: 2,768,640
# Non-trainable params: 1,792
# __________________________________________________________________________________________________

# %% [markdown]
# 두 개의 (256,256,3) 크기 입력으로 최종 (30,30,1) 출력을 만드는데 성공했습니다.
#
# 시험 삼아 임의의 (256,256,3) 크기의 입력을 넣어 나오는 (30,30) 출력을 시각화해보겠습니다.

# %%
x = tf.random.normal([1,256,256,3])
y = tf.random.uniform([1,256,256,3])

disc_out = Discriminator()(x, y)
plt.imshow(disc_out[0, ... ,0])
plt.colorbar()

# %% [markdown]
# ---

# %% [markdown]
# ## 4. 학습 및 테스트하기
#
# Generator와 Discriminator를 학습시켜보고, segment를 입력받아 도로 이미지를 생성해 봅시다.
# 일반적인 GAN의 손실함수에 L1을 추가로 이용했을 때 가장 실제에 가까운 이미지를 생성해 낼수 있습니다. 이번 실험에서도 두 가지 손실 함수를 모두 사용해 봅시다.

# %%
from tensorflow.keras import losses

bce = losses.BinaryCrossentropy(from_logits=False)
mae = losses.MeanAbsoluteError()

def get_gene_loss(fake_output, real_output, fake_disc):
    l1_loss = mae(real_output, fake_output)
    gene_loss = bce(tf.ones_like(fake_disc), fake_disc)
    return gene_loss, l1_loss

def get_disc_loss(fake_disc, real_disc):
    return bce(tf.zeros_like(fake_disc), fake_disc) + bce(tf.ones_like(real_disc), real_disc)

# %% [markdown]
# - Generator의 손실함수 (위 코드의 **get_gene_loss**)는 총 3개의 입력이 있습니다. 이 중 **fake_disc**는 Generator가 생성한 가짜 이미지를 Discriminator에 입력하여 얻어진 값이며, 실제 이미지를 뜻하는 "1"과 비교하기 위해 **tf.ones_like()**를 사용합니다. 또한 L1 손실을 계산하기 위해 생성한 가짜 이미지(**fake_output**)와 실제 이미지(**real_output**) 사이의 MAE(Mean Absolute Error)를 계산합니다.
#
#
# - Discriminator의 손실함수 (위 코드의 **get_disc_loss**)는 2개의 입력이 있으며, 이들은 가짜 및 진짜 이미지가 Discriminator에 각각 입력되어 얻어진 값입니다. Discriminator는 실제 이미지를 잘 구분해 내야 하므로 **real_disc**는 "1"로 채워진 벡터와 비교하고, **fake_disc**는 "0"으로 채워진 벡터와 비교합니다.
#
# optimizer는 논문과 동일하게 아래와 같이 설정합니다.

# %%
from tensorflow.keras import optimizers

gene_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)
disc_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)

# %% [markdown]
# 하나의 배치 크기만큼 데이터를 입력했을 때 가중치를 1회 업데이트하는 과정은 아래와 같이 구현했습니다.

# %%
@tf.function
def train_step(segment_map, real_road):
    with tf.GradientTape() as gene_tape, tf.GradientTape() as disc_tape:
        # Generator 예측
        fake_road = generator(segment_map, training=True)
        # Discriminator 예측
        fake_disc = discriminator(segment_map, fake_road, training=True)
        real_disc = discriminator(segment_map, real_road, training=True)
        # Generator 손실 계산
        gene_loss, l1_loss = get_gene_loss(fake_road, real_road, fake_disc)
        gene_total_loss = gene_loss + (100 * l1_loss) ## <===== L1 손실 반영 λ=100
        # Discrminator 손실 계산
        disc_loss = get_disc_loss(fake_disc, real_disc)
                
    gene_gradient = gene_tape.gradient(gene_total_loss, generator.trainable_variables)
    disc_gradient = disc_tape.gradient(disc_loss, discriminator.trainable_variables)
    
    gene_opt.apply_gradients(zip(gene_gradient, generator.trainable_variables))
    disc_opt.apply_gradients(zip(disc_gradient, discriminator.trainable_variables))
    return gene_loss, l1_loss, disc_loss

# %% [markdown]
# 앞서 정의한 함수를 이용해서 학습을 진행합니다.

# %%
EPOCHS = 10

generator = UNetGenerator()
discriminator = Discriminator()

for epoch in range(1, EPOCHS+1):
    for i, (segment_map, road) in enumerate(train_images):
        g_loss, l1_loss, d_loss = train_step(segment_map, road)

        # 20회 반복(iter)마다 손실을 출력합니다.
        if (i+1) % 20 == 0:  
            print(f"EPOCH[{epoch}] - STEP[{i+1}] \
                    \nGenerator_loss:{g_loss.numpy():.4f} \
                    \nL1_loss:{l1_loss.numpy():.4f} \
                    \nDiscriminator_loss:{d_loss.numpy():.4f}", end="\n\n")
# Out:
# EPOCH[1] - STEP[20]
# Generator_loss:0.8607
# L1_loss:0.2339
# Discriminator_loss:1.4566
#
# EPOCH[1] - STEP[40]
# Generator_loss:0.7169
# L1_loss:0.2605
# Discriminator_loss:1.3720
#
# EPOCH[1] - STEP[60]
# Generator_loss:0.9465
# L1_loss:0.2167
# Discriminator_loss:1.2111
#
# EPOCH[1] - STEP[80]
# Generator_loss:1.1071
# L1_loss:0.2355
# Discriminator_loss:1.0831
#
# EPOCH[1] - STEP[100]
# Generator_loss:0.9081
# L1_loss:0.2085
# Discriminator_loss:1.1871
#
# EPOCH[1] - STEP[120]
# Generator_loss:1.4486
# L1_loss:0.1924
# Discriminator_loss:1.2626
#
# EPOCH[1] - STEP[140]
# Generator_loss:0.8171
# L1_loss:0.1998
# Discriminator_loss:1.3865
#
# EPOCH[1] - STEP[160]
# Generator_loss:1.3374
# L1_loss:0.2115
# Discriminator_loss:0.9316
#
# EPOCH[1] - STEP[180]
# Generator_loss:0.6150
# L1_loss:0.2063
# Discriminator_loss:1.0950
#
# EPOCH[1] - STEP[200]
# Generator_loss:1.8110
# L1_loss:0.1807
# Discriminator_loss:1.1801
#
# EPOCH[1] - STEP[220]
# Generator_loss:1.7358
# L1_loss:0.1839
# Discriminator_loss:0.5413
#
# EPOCH[1] - STEP[240]
# Generator_loss:1.8203
# L1_loss:0.2518
# Discriminator_loss:0.3454
#
# EPOCH[2] - STEP[20]
# Generator_loss:1.8706
# L1_loss:0.1600
# Discriminator_loss:0.4790
#
# EPOCH[2] - STEP[40]
# Generator_loss:0.9107
# L1_loss:0.1536
# Discriminator_loss:1.0094
#
# EPOCH[2] - STEP[60]
# Generator_loss:1.1846
# L1_loss:0.2039
# Discriminator_loss:0.8599
#
# EPOCH[2] - STEP[80]
# Generator_loss:1.8293
# L1_loss:0.1669
# Discriminator_loss:0.7596
#
# EPOCH[2] - STEP[100]
# Generator_loss:1.2708
# L1_loss:0.1487
# Discriminator_loss:0.7436
#
# EPOCH[2] - STEP[120]
# Generator_loss:0.8670
# L1_loss:0.1714
# Discriminator_loss:0.9698
#
# EPOCH[2] - STEP[140]
# Generator_loss:1.5045
# L1_loss:0.1982
# Discriminator_loss:0.4065
#
# EPOCH[2] - STEP[160]
# Generator_loss:1.6213
# L1_loss:0.2175
# Discriminator_loss:0.5696
#
# EPOCH[2] - STEP[180]
# Generator_loss:2.0608
# L1_loss:0.1620
# Discriminator_loss:0.4415
#
# EPOCH[2] - STEP[200]
# Generator_loss:2.2114
# L1_loss:0.1552
# Discriminator_loss:1.2052
#
# EPOCH[2] - STEP[220]
# Generator_loss:1.4274
# L1_loss:0.1465
# Discriminator_loss:0.8980
#
# EPOCH[2] - STEP[240]
# Generator_loss:0.6676
# L1_loss:0.1818
# Discriminator_loss:1.3242
#
# EPOCH[3] - STEP[20]
# Generator_loss:0.7989
# L1_loss:0.1746
# Discriminator_loss:0.9389
#
# EPOCH[3] - STEP[40]
# Generator_loss:1.7988
# L1_loss:0.1851
# Discriminator_loss:1.3753
#
# EPOCH[3] - STEP[60]
# Generator_loss:2.1232
# L1_loss:0.1593
# Discriminator_loss:0.4306
#
# EPOCH[3] - STEP[80]
# Generator_loss:1.5516
# L1_loss:0.1730
# Discriminator_loss:1.1526
#
# EPOCH[3] - STEP[100]
# Generator_loss:0.9262
# L1_loss:0.2411
# Discriminator_loss:0.7398
#
# EPOCH[3] - STEP[120]
# Generator_loss:2.2923
# L1_loss:0.2195
# Discriminator_loss:0.2519
#
# EPOCH[3] - STEP[140]
# Generator_loss:2.4669
# L1_loss:0.1899
# Discriminator_loss:0.3097
#
# EPOCH[3] - STEP[160]
# Generator_loss:1.4470
# L1_loss:0.2001
# Discriminator_loss:0.5375
#
# EPOCH[3] - STEP[180]
# Generator_loss:1.9130
# L1_loss:0.1707
# Discriminator_loss:0.4296
#
# EPOCH[3] - STEP[200]
# Generator_loss:0.6660
# L1_loss:0.1939
# Discriminator_loss:1.1263
#
# EPOCH[3] - STEP[220]
# Generator_loss:1.5580
# L1_loss:0.1505
# Discriminator_loss:0.5243
#
# EPOCH[3] - STEP[240]
# Generator_loss:0.6989
# L1_loss:0.2038
# Discriminator_loss:0.9671
#
# EPOCH[4] - STEP[20]
# Generator_loss:0.3803
# L1_loss:0.1778
# Discriminator_loss:1.8925
#
# EPOCH[4] - STEP[40]
# Generator_loss:1.9063
# L1_loss:0.1826
# Discriminator_loss:0.4846
#
# EPOCH[4] - STEP[60]
# Generator_loss:0.6255
# L1_loss:0.1724
# Discriminator_loss:0.9769
#
# EPOCH[4] - STEP[80]
# Generator_loss:1.9378
# L1_loss:0.1677
# Discriminator_loss:0.6265
#
# EPOCH[4] - STEP[100]
# Generator_loss:1.3890
# L1_loss:0.1794
# Discriminator_loss:0.5482
#
# EPOCH[4] - STEP[120]
# Generator_loss:0.6287
# L1_loss:0.1772
# Discriminator_loss:1.1406
#
# EPOCH[4] - STEP[140]
# Generator_loss:0.9773
# L1_loss:0.1811
# Discriminator_loss:0.5992
#
# EPOCH[4] - STEP[160]
# Generator_loss:0.8705
# L1_loss:0.1849
# Discriminator_loss:1.0791
#
# EPOCH[4] - STEP[180]
# Generator_loss:2.9255
# L1_loss:0.1684
# Discriminator_loss:0.3150
#
# EPOCH[4] - STEP[200]
# Generator_loss:0.7332
# L1_loss:0.1813
# Discriminator_loss:0.8786
#
# EPOCH[4] - STEP[220]
# Generator_loss:0.5476
# L1_loss:0.1871
# Discriminator_loss:1.0546
#
# EPOCH[4] - STEP[240]
# Generator_loss:1.4622
# L1_loss:0.1968
# Discriminator_loss:0.4571
#
# EPOCH[5] - STEP[20]
# Generator_loss:2.4678
# L1_loss:0.1684
# Discriminator_loss:0.9327
#
# EPOCH[5] - STEP[40]
# Generator_loss:1.8912
# L1_loss:0.1774
# Discriminator_loss:0.7560
#
# EPOCH[5] - STEP[60]
# Generator_loss:1.0894
# L1_loss:0.1577
# Discriminator_loss:1.0816
#
# EPOCH[5] - STEP[80]
# Generator_loss:0.6159
# L1_loss:0.1533
# Discriminator_loss:1.4299
#
# EPOCH[5] - STEP[100]
# Generator_loss:2.2502
# L1_loss:0.1872
# Discriminator_loss:0.6071
#
# EPOCH[5] - STEP[120]
# Generator_loss:2.3220
# L1_loss:0.2276
# Discriminator_loss:0.6992
#
# EPOCH[5] - STEP[140]
# Generator_loss:1.4855
# L1_loss:0.1785
# Discriminator_loss:0.4826
#
# EPOCH[5] - STEP[160]
# Generator_loss:1.4008
# L1_loss:0.1523
# Discriminator_loss:0.6070
# EPOCH[5] - STEP[180]
# Generator_loss:1.4185
# L1_loss:0.1803
# Discriminator_loss:0.6441
#
# EPOCH[5] - STEP[200]
# Generator_loss:1.3277
# L1_loss:0.2036
# Discriminator_loss:0.6650
#
# EPOCH[5] - STEP[220]
# Generator_loss:3.6771
# L1_loss:0.1852
# Discriminator_loss:2.0748
#
# EPOCH[5] - STEP[240]
# Generator_loss:1.6488
# L1_loss:0.1823
# Discriminator_loss:1.0904
#
# EPOCH[6] - STEP[20]
# Generator_loss:1.6161
# L1_loss:0.1642
# Discriminator_loss:0.9514
#
# EPOCH[6] - STEP[40]
# Generator_loss:0.3453
# L1_loss:0.2172
# Discriminator_loss:1.9787
#
# EPOCH[6] - STEP[60]
# Generator_loss:2.5827
# L1_loss:0.1857
# Discriminator_loss:0.4694
#
# EPOCH[6] - STEP[80]
# Generator_loss:0.6163
# L1_loss:0.1742
# Discriminator_loss:1.0172
#
# EPOCH[6] - STEP[100]
# Generator_loss:0.6848
# L1_loss:0.2099
# Discriminator_loss:0.9076
#
# EPOCH[6] - STEP[120]
# Generator_loss:2.4999
# L1_loss:0.1928
# Discriminator_loss:0.7522
#
# EPOCH[6] - STEP[140]
# Generator_loss:1.6869
# L1_loss:0.2117
# Discriminator_loss:0.8472
#
# EPOCH[6] - STEP[160]
# Generator_loss:0.9161
# L1_loss:0.2014
# Discriminator_loss:0.6317
#
# EPOCH[6] - STEP[180]
# Generator_loss:1.9585
# L1_loss:0.1487
# Discriminator_loss:1.1571
#
# EPOCH[6] - STEP[200]
# Generator_loss:1.7477
# L1_loss:0.1384
# Discriminator_loss:1.3231
#
# EPOCH[6] - STEP[220]
# Generator_loss:1.0473
# L1_loss:0.1670
# Discriminator_loss:0.8778
#
# EPOCH[6] - STEP[240]
# Generator_loss:2.3742
# L1_loss:0.1610
# Discriminator_loss:0.7932
#
# EPOCH[7] - STEP[20]
# Generator_loss:0.8922
# L1_loss:0.1980
# Discriminator_loss:0.6003
#
# EPOCH[7] - STEP[40]
# Generator_loss:0.7728
# L1_loss:0.2040
# Discriminator_loss:0.7830
#
# EPOCH[7] - STEP[60]
# Generator_loss:2.2628
# L1_loss:0.1722
# Discriminator_loss:0.5713
#
# EPOCH[7] - STEP[80]
# Generator_loss:1.1942
# L1_loss:0.1693
# Discriminator_loss:0.7628
#
# EPOCH[7] - STEP[100]
# Generator_loss:1.5681
# L1_loss:0.1547
# Discriminator_loss:0.8456
#
# EPOCH[7] - STEP[120]
# Generator_loss:1.4890
# L1_loss:0.2135
# Discriminator_loss:0.4479
#
# EPOCH[7] - STEP[140]
# Generator_loss:0.6398
# L1_loss:0.1974
# Discriminator_loss:1.0087
#
# EPOCH[7] - STEP[160]
# Generator_loss:1.1772
# L1_loss:0.1910
# Discriminator_loss:0.7636
#
# EPOCH[7] - STEP[180]
# Generator_loss:2.4531
# L1_loss:0.1827
# Discriminator_loss:0.7467
#
# EPOCH[7] - STEP[200]
# Generator_loss:0.4608
# L1_loss:0.1753
# Discriminator_loss:1.1741
#
# EPOCH[7] - STEP[220]
# Generator_loss:1.2765
# L1_loss:0.1460
# Discriminator_loss:0.5468
#
# EPOCH[7] - STEP[240]
# Generator_loss:0.9497
# L1_loss:0.1646
# Discriminator_loss:0.7529
#
# EPOCH[8] - STEP[20]
# Generator_loss:3.4045
# L1_loss:0.1701
# Discriminator_loss:0.9627
#
# EPOCH[8] - STEP[40]
# Generator_loss:0.8154
# L1_loss:0.1792
# Discriminator_loss:0.7093
#
# EPOCH[8] - STEP[60]
# Generator_loss:1.2861
# L1_loss:0.1655
# Discriminator_loss:0.5208
#
# EPOCH[8] - STEP[80]
# Generator_loss:0.9589
# L1_loss:0.1640
# Discriminator_loss:0.9230
#
# EPOCH[8] - STEP[100]
# Generator_loss:0.6713
# L1_loss:0.1515
# Discriminator_loss:1.3673
#
# EPOCH[8] - STEP[120]
# Generator_loss:1.8981
# L1_loss:0.1771
# Discriminator_loss:0.6178
#
# EPOCH[8] - STEP[140]
# Generator_loss:1.8672
# L1_loss:0.1799
# Discriminator_loss:0.9666
#
# EPOCH[8] - STEP[160]
# Generator_loss:2.2075
# L1_loss:0.2325
# Discriminator_loss:0.2763
#
# EPOCH[8] - STEP[180]
# Generator_loss:2.3829
# L1_loss:0.1723
# Discriminator_loss:0.5190
#
# EPOCH[8] - STEP[200]
# Generator_loss:0.5483
# L1_loss:0.1774
# Discriminator_loss:1.1822
#
# EPOCH[8] - STEP[220]
# Generator_loss:0.6560
# L1_loss:0.1454
# Discriminator_loss:1.0393
#
# EPOCH[8] - STEP[240]
# Generator_loss:1.5582
# L1_loss:0.1611
# Discriminator_loss:1.3292
#
# EPOCH[9] - STEP[20]
# Generator_loss:0.4482
# L1_loss:0.1734
# Discriminator_loss:1.2080
#
# EPOCH[9] - STEP[40]
# Generator_loss:2.4657
# L1_loss:0.1694
# Discriminator_loss:0.7484
#
# EPOCH[9] - STEP[60]
# Generator_loss:0.7944
# L1_loss:0.1925
# Discriminator_loss:0.8606
#
# EPOCH[9] - STEP[80]
# Generator_loss:1.5069
# L1_loss:0.1912
# Discriminator_loss:1.4659
#
# EPOCH[9] - STEP[100]
# Generator_loss:2.4104
# L1_loss:0.1921
# Discriminator_loss:0.5638
#
# EPOCH[9] - STEP[120]
# Generator_loss:1.1170
# L1_loss:0.1551
# Discriminator_loss:0.7472
#
# EPOCH[9] - STEP[140]
# Generator_loss:1.8188
# L1_loss:0.1725
# Discriminator_loss:0.6044
#
# EPOCH[9] - STEP[160]
# Generator_loss:2.7187
# L1_loss:0.1521
# Discriminator_loss:1.9048
#
# EPOCH[9] - STEP[180]
# Generator_loss:2.1144
# L1_loss:0.1962
# Discriminator_loss:1.3938
#
# EPOCH[9] - STEP[200]
# Generator_loss:1.3744
# L1_loss:0.1911
# Discriminator_loss:0.6758
#
# EPOCH[9] - STEP[220]
# Generator_loss:1.8941
# L1_loss:0.2060
# Discriminator_loss:0.2523
#
# EPOCH[9] - STEP[240]
# Generator_loss:0.7835
# L1_loss:0.1584
# Discriminator_loss:0.9725
#
# EPOCH[10] - STEP[20]
# Generator_loss:1.7007
# L1_loss:0.1867
# Discriminator_loss:0.5915
#
# EPOCH[10] - STEP[40]
# Generator_loss:0.5512
# L1_loss:0.1621
# Discriminator_loss:1.4757
#
# EPOCH[10] - STEP[60]
# Generator_loss:1.7230
# L1_loss:0.1568
# Discriminator_loss:0.6752
#
# EPOCH[10] - STEP[80]
# Generator_loss:1.1884
# L1_loss:0.1968
# Discriminator_loss:0.4999
# EPOCH[10] - STEP[100]
# Generator_loss:2.9783
# L1_loss:0.1896
# Discriminator_loss:0.3746
#
# EPOCH[10] - STEP[120]
# Generator_loss:1.3688
# L1_loss:0.1876
# Discriminator_loss:0.7812
#
# EPOCH[10] - STEP[140]
# Generator_loss:2.1294
# L1_loss:0.2045
# Discriminator_loss:0.7305
#
# EPOCH[10] - STEP[160]
# Generator_loss:0.3202
# L1_loss:0.1749
# Discriminator_loss:1.7979
#
# EPOCH[10] - STEP[180]
# Generator_loss:2.7894
# L1_loss:0.1540
# Discriminator_loss:1.2018
#
# EPOCH[10] - STEP[200]
# Generator_loss:0.8125
# L1_loss:0.1600
# Discriminator_loss:1.2937
#
# EPOCH[10] - STEP[220]
# Generator_loss:2.5319
# L1_loss:0.1760
# Discriminator_loss:0.6137
#
# EPOCH[10] - STEP[240]
# Generator_loss:3.7062
# L1_loss:0.1586
# Discriminator_loss:1.2098

# %% [markdown]
# 아래 코드로 짧게나마 학습해 본 모델에 채색을 시켜봅시다.
# 테스트는 이미지는 val image로 확인해보겠습니다.

# %%
val_path
# Out:
# '/home/ssac27/aiffel/conditional_generation/cityscapes/val/'

# %%
test_ind = 0

f = val_path + os.listdir(val_path)[test_ind]
segment_map,road = load_img(f)

pred = generator(tf.expand_dims(segment_map, 0))
pred = denormalize(pred)

plt.figure(figsize=(20,10))
plt.subplot(1,3,1); plt.imshow(denormalize(segment_map))
plt.subplot(1,3,2); plt.imshow(pred[0])
plt.subplot(1,3,3); plt.imshow(denormalize(road))

# %% [markdown]
# #### epoch 10
# 결과를 보면 오른쪽의 이미지와 흡사한 모습이 보이긴 하지만, 전체적으로 noise가 심한 모습이 보입니다.
#
# 반복횟수를 10 -> 50으로 증가해서 결과를 다시 확인 해보겠습니다.

# %% [markdown]
# #### epoch 50

# %%
EPOCHS = 50

generator = UNetGenerator()
discriminator = Discriminator()

for epoch in range(1, EPOCHS+1):
    for i, (segment_map, road) in enumerate(train_images):
        g_loss, l1_loss, d_loss = train_step(segment_map, road)

        # 20회 반복(iter)마다 손실을 출력합니다.
        if (i+1) % 20 == 0:  
            print(f"EPOCH[{epoch}] - STEP[{i+1}] \
                    \nGenerator_loss:{g_loss.numpy():.4f} \
                    \nL1_loss:{l1_loss.numpy():.4f} \
                    \nDiscriminator_loss:{d_loss.numpy():.4f}", end="\n\n")
# Out:
# EPOCH[1] - STEP[20]
# Generator_loss:0.7698
# L1_loss:0.1779
# Discriminator_loss:1.3471
#
# EPOCH[1] - STEP[40]
# Generator_loss:0.7332
# L1_loss:0.2205
# Discriminator_loss:1.3341
#
# EPOCH[1] - STEP[60]
# Generator_loss:1.0177
# L1_loss:0.1739
# Discriminator_loss:1.3167
#
# EPOCH[1] - STEP[80]
# Generator_loss:0.9638
# L1_loss:0.2204
# Discriminator_loss:1.3202
#
# EPOCH[1] - STEP[100]
# Generator_loss:1.3778
# L1_loss:0.2251
# Discriminator_loss:0.8427
#
# EPOCH[1] - STEP[120]
# Generator_loss:1.0060
# L1_loss:0.2406
# Discriminator_loss:1.1190
#
# EPOCH[1] - STEP[140]
# Generator_loss:1.2313
# L1_loss:0.1776
# Discriminator_loss:1.1144
#
# EPOCH[1] - STEP[160]
# Generator_loss:1.2575
# L1_loss:0.1593
# Discriminator_loss:1.0801
#
# EPOCH[1] - STEP[180]
# Generator_loss:1.6226
# L1_loss:0.1755
# Discriminator_loss:0.9320
#
# EPOCH[1] - STEP[200]
# Generator_loss:1.3059
# L1_loss:0.1886
# Discriminator_loss:0.9860
#
# EPOCH[1] - STEP[220]
# Generator_loss:1.5222
# L1_loss:0.2093
# Discriminator_loss:1.1732
#
# EPOCH[1] - STEP[240]
# Generator_loss:1.3457
# L1_loss:0.1842
# Discriminator_loss:0.6128
#
# EPOCH[2] - STEP[20]
# Generator_loss:1.2365
# L1_loss:0.2090
# Discriminator_loss:0.5996
#
# EPOCH[2] - STEP[40]
# Generator_loss:1.5907
# L1_loss:0.1838
# Discriminator_loss:1.4903
#
# EPOCH[2] - STEP[60]
# Generator_loss:2.0224
# L1_loss:0.1718
# Discriminator_loss:0.9004
#
# EPOCH[2] - STEP[80]
# Generator_loss:2.7049
# L1_loss:0.1648
# Discriminator_loss:0.6866
#
# EPOCH[2] - STEP[100]
# Generator_loss:1.8037
# L1_loss:0.1709
# Discriminator_loss:0.3881
#
# EPOCH[2] - STEP[120]
# Generator_loss:2.8121
# L1_loss:0.1783
# Discriminator_loss:1.3616
#
# EPOCH[2] - STEP[140]
# Generator_loss:2.1949
# L1_loss:0.2021
# Discriminator_loss:1.1563
#
# EPOCH[2] - STEP[160]
# Generator_loss:1.5470
# L1_loss:0.1917
# Discriminator_loss:0.4128
#
# EPOCH[2] - STEP[180]
# Generator_loss:0.9972
# L1_loss:0.1926
# Discriminator_loss:1.7955
#
# EPOCH[2] - STEP[200]
# Generator_loss:2.5049
# L1_loss:0.1467
# Discriminator_loss:0.9373
#
# EPOCH[2] - STEP[220]
# Generator_loss:1.3682
# L1_loss:0.1725
# Discriminator_loss:1.1615
#
# EPOCH[2] - STEP[240]
# Generator_loss:1.8462
# L1_loss:0.2083
# Discriminator_loss:0.3281
#
# EPOCH[3] - STEP[20]
# Generator_loss:2.1991
# L1_loss:0.2246
# Discriminator_loss:0.6104
#
# EPOCH[3] - STEP[40]
# Generator_loss:0.9364
# L1_loss:0.2267
# Discriminator_loss:0.8737
#
# EPOCH[3] - STEP[60]
# Generator_loss:1.3082
# L1_loss:0.1819
# Discriminator_loss:0.5834
#
# EPOCH[3] - STEP[80]
# Generator_loss:1.2590
# L1_loss:0.1769
# Discriminator_loss:1.1338
#
# EPOCH[3] - STEP[100]
# Generator_loss:2.1171
# L1_loss:0.1503
# Discriminator_loss:0.8622
#
# EPOCH[3] - STEP[120]
# Generator_loss:2.5817
# L1_loss:0.1774
# Discriminator_loss:0.7282
#
# EPOCH[3] - STEP[140]
# Generator_loss:2.4541
# L1_loss:0.1954
# Discriminator_loss:0.3407
#
# EPOCH[3] - STEP[160]
# Generator_loss:0.8737
# L1_loss:0.1866
# Discriminator_loss:0.9126
#
# EPOCH[3] - STEP[180]
# Generator_loss:2.8618
# L1_loss:0.1511
# Discriminator_loss:3.4469
#
# EPOCH[3] - STEP[200]
# Generator_loss:1.6427
# L1_loss:0.1676
# Discriminator_loss:0.8348
#
# EPOCH[3] - STEP[220]
# Generator_loss:1.4809
# L1_loss:0.2041
# Discriminator_loss:0.4079
#
# EPOCH[3] - STEP[240]
# Generator_loss:1.6004
# L1_loss:0.2224
# Discriminator_loss:1.7330
#
# EPOCH[4] - STEP[20]
# Generator_loss:1.7185
# L1_loss:0.1908
# Discriminator_loss:0.5485
#
# EPOCH[4] - STEP[40]
# Generator_loss:1.4468
# L1_loss:0.1659
# Discriminator_loss:1.3482
#
# EPOCH[4] - STEP[60]
# Generator_loss:0.8660
# L1_loss:0.1858
# Discriminator_loss:0.8845
#
# EPOCH[4] - STEP[80]
# Generator_loss:1.6714
# L1_loss:0.1876
# Discriminator_loss:0.6534
#
# EPOCH[4] - STEP[100]
# Generator_loss:1.4076
# L1_loss:0.2147
# Discriminator_loss:0.3353
#
# EPOCH[4] - STEP[120]
# Generator_loss:2.1111
# L1_loss:0.1995
# Discriminator_loss:0.3634
#
# EPOCH[4] - STEP[140]
# Generator_loss:0.8767
# L1_loss:0.1546
# Discriminator_loss:1.1242
#
# EPOCH[4] - STEP[160]
# Generator_loss:1.5191
# L1_loss:0.2061
# Discriminator_loss:0.5358
#
# EPOCH[4] - STEP[180]
# Generator_loss:0.7439
# L1_loss:0.2036
# Discriminator_loss:0.7960
#
# EPOCH[4] - STEP[200]
# Generator_loss:1.9881
# L1_loss:0.2080
# Discriminator_loss:0.3683
#
# EPOCH[4] - STEP[220]
# Generator_loss:1.0256
# L1_loss:0.1639
# Discriminator_loss:1.1564
#
# EPOCH[4] - STEP[240]
# Generator_loss:1.9731
# L1_loss:0.1938
# Discriminator_loss:0.4889
#
# EPOCH[5] - STEP[20]
# Generator_loss:1.5135
# L1_loss:0.1704
# Discriminator_loss:1.2803
#
# EPOCH[5] - STEP[40]
# Generator_loss:2.0577
# L1_loss:0.2138
# Discriminator_loss:0.5764
#
# EPOCH[5] - STEP[60]
# Generator_loss:1.6527
# L1_loss:0.1587
# Discriminator_loss:1.1981
#
# EPOCH[5] - STEP[80]
# Generator_loss:2.0885
# L1_loss:0.1608
# Discriminator_loss:0.5856
#
# EPOCH[5] - STEP[100]
# Generator_loss:2.3550
# L1_loss:0.1652
# Discriminator_loss:0.8633
#
# EPOCH[5] - STEP[120]
# Generator_loss:1.5128
# L1_loss:0.1640
# Discriminator_loss:1.1952
#
# EPOCH[5] - STEP[140]
# Generator_loss:1.6552
# L1_loss:0.2032
# Discriminator_loss:0.3363
#
# EPOCH[5] - STEP[160]
# Generator_loss:1.9150
# L1_loss:0.1985
# Discriminator_loss:0.3738
# EPOCH[5] - STEP[180]
# Generator_loss:2.0647
# L1_loss:0.1828
# Discriminator_loss:0.5440
#
# EPOCH[5] - STEP[200]
# Generator_loss:1.5285
# L1_loss:0.1694
# Discriminator_loss:0.6645
#
# EPOCH[5] - STEP[220]
# Generator_loss:2.9120
# L1_loss:0.1699
# Discriminator_loss:0.9254
#
# EPOCH[5] - STEP[240]
# Generator_loss:0.9333
# L1_loss:0.1906
# Discriminator_loss:0.8108
#
# EPOCH[6] - STEP[20]
# Generator_loss:1.7079
# L1_loss:0.1506
# Discriminator_loss:0.5889
#
# EPOCH[6] - STEP[40]
# Generator_loss:2.3626
# L1_loss:0.1690
# Discriminator_loss:1.6760
#
# EPOCH[6] - STEP[60]
# Generator_loss:2.5730
# L1_loss:0.2003
# Discriminator_loss:0.5849
#
# EPOCH[6] - STEP[80]
# Generator_loss:2.2147
# L1_loss:0.1807
# Discriminator_loss:0.9757
#
# EPOCH[6] - STEP[100]
# Generator_loss:1.8395
# L1_loss:0.1505
# Discriminator_loss:0.7186
#
# EPOCH[6] - STEP[120]
# Generator_loss:2.0753
# L1_loss:0.1843
# Discriminator_loss:0.4115
#
# EPOCH[6] - STEP[140]
# Generator_loss:2.7530
# L1_loss:0.1581
# Discriminator_loss:2.1721
#
# EPOCH[6] - STEP[160]
# Generator_loss:1.0557
# L1_loss:0.1686
# Discriminator_loss:1.6303
#
# EPOCH[6] - STEP[180]
# Generator_loss:1.8647
# L1_loss:0.2195
# Discriminator_loss:0.6037
#
# EPOCH[6] - STEP[200]
# Generator_loss:1.3279
# L1_loss:0.2199
# Discriminator_loss:0.3985
#
# EPOCH[6] - STEP[220]
# Generator_loss:0.5846
# L1_loss:0.1745
# Discriminator_loss:1.1872
#
# EPOCH[6] - STEP[240]
# Generator_loss:2.6594
# L1_loss:0.1657
# Discriminator_loss:0.8059
#
# EPOCH[7] - STEP[20]
# Generator_loss:2.1001
# L1_loss:0.1583
# Discriminator_loss:0.9848
#
# EPOCH[7] - STEP[40]
# Generator_loss:1.7676
# L1_loss:0.1987
# Discriminator_loss:0.3364
#
# EPOCH[7] - STEP[60]
# Generator_loss:1.1678
# L1_loss:0.1991
# Discriminator_loss:0.5676
#
# EPOCH[7] - STEP[80]
# Generator_loss:1.5157
# L1_loss:0.1637
# Discriminator_loss:1.1608
#
# EPOCH[7] - STEP[100]
# Generator_loss:1.4576
# L1_loss:0.1955
# Discriminator_loss:0.5686
#
# EPOCH[7] - STEP[120]
# Generator_loss:0.4632
# L1_loss:0.1955
# Discriminator_loss:1.3047
#
# EPOCH[7] - STEP[140]
# Generator_loss:1.5269
# L1_loss:0.2050
# Discriminator_loss:0.3377
#
# EPOCH[7] - STEP[160]
# Generator_loss:1.1461
# L1_loss:0.1539
# Discriminator_loss:0.7572
#
# EPOCH[7] - STEP[180]
# Generator_loss:0.8923
# L1_loss:0.1481
# Discriminator_loss:1.5124
#
# EPOCH[7] - STEP[200]
# Generator_loss:1.0180
# L1_loss:0.1690
# Discriminator_loss:0.6791
#
# EPOCH[7] - STEP[220]
# Generator_loss:2.5647
# L1_loss:0.1910
# Discriminator_loss:0.4960
#
# EPOCH[7] - STEP[240]
# Generator_loss:1.4703
# L1_loss:0.1922
# Discriminator_loss:1.9742
#
# EPOCH[8] - STEP[20]
# Generator_loss:0.3959
# L1_loss:0.1487
# Discriminator_loss:1.3230
#
# EPOCH[8] - STEP[40]
# Generator_loss:0.1357
# L1_loss:0.1674
# Discriminator_loss:2.4246
#
# EPOCH[8] - STEP[60]
# Generator_loss:1.0751
# L1_loss:0.1814
# Discriminator_loss:0.5084
#
# EPOCH[8] - STEP[80]
# Generator_loss:0.4953
# L1_loss:0.1842
# Discriminator_loss:1.1507
#
# EPOCH[8] - STEP[100]
# Generator_loss:0.7729
# L1_loss:0.1599
# Discriminator_loss:0.8363
#
# EPOCH[8] - STEP[120]
# Generator_loss:1.8663
# L1_loss:0.1535
# Discriminator_loss:0.8459
#
# EPOCH[8] - STEP[140]
# Generator_loss:0.9895
# L1_loss:0.1692
# Discriminator_loss:0.8466
#
# EPOCH[8] - STEP[160]
# Generator_loss:1.2703
# L1_loss:0.1607
# Discriminator_loss:1.2645
#
# EPOCH[8] - STEP[180]
# Generator_loss:1.9507
# L1_loss:0.1403
# Discriminator_loss:0.7060
#
# EPOCH[8] - STEP[200]
# Generator_loss:2.8290
# L1_loss:0.1768
# Discriminator_loss:2.0839
#
# EPOCH[8] - STEP[220]
# Generator_loss:0.6669
# L1_loss:0.1502
# Discriminator_loss:1.1856
#
# EPOCH[8] - STEP[240]
# Generator_loss:1.1709
# L1_loss:0.2011
# Discriminator_loss:0.4741
#
# EPOCH[9] - STEP[20]
# Generator_loss:1.3928
# L1_loss:0.1333
# Discriminator_loss:1.3755
#
# EPOCH[9] - STEP[40]
# Generator_loss:1.5511
# L1_loss:0.1823
# Discriminator_loss:0.9697
#
# EPOCH[9] - STEP[60]
# Generator_loss:0.5428
# L1_loss:0.1448
# Discriminator_loss:1.5172
#
# EPOCH[9] - STEP[80]
# Generator_loss:1.4263
# L1_loss:0.1786
# Discriminator_loss:0.7367
#
# EPOCH[9] - STEP[100]
# Generator_loss:1.6726
# L1_loss:0.1373
# Discriminator_loss:1.6600
#
# EPOCH[9] - STEP[120]
# Generator_loss:2.7241
# L1_loss:0.1398
# Discriminator_loss:1.3629
#
# EPOCH[9] - STEP[140]
# Generator_loss:2.9560
# L1_loss:0.1389
# Discriminator_loss:1.3612
#
# EPOCH[9] - STEP[160]
# Generator_loss:1.7142
# L1_loss:0.1835
# Discriminator_loss:0.4456
#
# EPOCH[9] - STEP[180]
# Generator_loss:1.0132
# L1_loss:0.1684
# Discriminator_loss:0.9597
#
# EPOCH[9] - STEP[200]
# Generator_loss:2.0234
# L1_loss:0.1788
# Discriminator_loss:0.7077
#
# EPOCH[9] - STEP[220]
# Generator_loss:1.4697
# L1_loss:0.1601
# Discriminator_loss:0.7984
#
# EPOCH[9] - STEP[240]
# Generator_loss:0.9302
# L1_loss:0.2094
# Discriminator_loss:0.8680
#
# EPOCH[10] - STEP[20]
# Generator_loss:1.2680
# L1_loss:0.1567
# Discriminator_loss:0.6796
#
# EPOCH[10] - STEP[40]
# Generator_loss:1.1127
# L1_loss:0.1715
# Discriminator_loss:0.5765
#
# EPOCH[10] - STEP[60]
# Generator_loss:0.6604
# L1_loss:0.1567
# Discriminator_loss:1.3036
#
# EPOCH[10] - STEP[80]
# Generator_loss:0.9358
# L1_loss:0.1746
# Discriminator_loss:0.7620
# EPOCH[10] - STEP[100]
# Generator_loss:1.4750
# L1_loss:0.1589
# Discriminator_loss:0.8836
#
# EPOCH[10] - STEP[120]
# Generator_loss:2.0879
# L1_loss:0.1732
# Discriminator_loss:1.0963
#
# EPOCH[10] - STEP[140]
# Generator_loss:1.3596
# L1_loss:0.1594
# Discriminator_loss:0.9404
#
# EPOCH[10] - STEP[160]
# Generator_loss:2.0384
# L1_loss:0.2208
# Discriminator_loss:0.2929
#
# EPOCH[10] - STEP[180]
# Generator_loss:0.7076
# L1_loss:0.1867
# Discriminator_loss:0.8568
#
# EPOCH[10] - STEP[200]
# Generator_loss:0.8284
# L1_loss:0.1922
# Discriminator_loss:0.6924
#
# EPOCH[10] - STEP[220]
# Generator_loss:3.0612
# L1_loss:0.2001
# Discriminator_loss:0.2087
#
# EPOCH[10] - STEP[240]
# Generator_loss:1.2454
# L1_loss:0.1643
# Discriminator_loss:0.7218
#
# EPOCH[11] - STEP[20]
# Generator_loss:1.3410
# L1_loss:0.1724
# Discriminator_loss:0.4889
#
# EPOCH[11] - STEP[40]
# Generator_loss:1.0546
# L1_loss:0.1714
# Discriminator_loss:0.6084
#
# EPOCH[11] - STEP[60]
# Generator_loss:0.6992
# L1_loss:0.1685
# Discriminator_loss:1.4887
#
# EPOCH[11] - STEP[80]
# Generator_loss:2.5821
# L1_loss:0.1948
# Discriminator_loss:0.7159
#
# EPOCH[11] - STEP[100]
# Generator_loss:2.0721
# L1_loss:0.1682
# Discriminator_loss:0.5326
#
# EPOCH[11] - STEP[120]
# Generator_loss:1.3182
# L1_loss:0.1842
# Discriminator_loss:0.4424
#
# EPOCH[11] - STEP[140]
# Generator_loss:0.5722
# L1_loss:0.2037
# Discriminator_loss:0.9963
#
# EPOCH[11] - STEP[160]
# Generator_loss:1.3428
# L1_loss:0.1879
# Discriminator_loss:0.6065
#
# EPOCH[11] - STEP[180]
# Generator_loss:1.2985
# L1_loss:0.1687
# Discriminator_loss:0.4957
#
# EPOCH[11] - STEP[200]
# Generator_loss:2.0581
# L1_loss:0.2065
# Discriminator_loss:0.4931
#
# EPOCH[11] - STEP[220]
# Generator_loss:1.3659
# L1_loss:0.1648
# Discriminator_loss:0.6327
#
# EPOCH[11] - STEP[240]
# Generator_loss:1.1214
# L1_loss:0.1481
# Discriminator_loss:1.6592
#
# EPOCH[12] - STEP[20]
# Generator_loss:3.1618
# L1_loss:0.1712
# Discriminator_loss:0.7844
#
# EPOCH[12] - STEP[40]
# Generator_loss:1.5329
# L1_loss:0.1698
# Discriminator_loss:0.5162
#
# EPOCH[12] - STEP[60]
# Generator_loss:2.2689
# L1_loss:0.1744
# Discriminator_loss:0.7527
#
# EPOCH[12] - STEP[80]
# Generator_loss:1.3712
# L1_loss:0.1486
# Discriminator_loss:1.2200
#
# EPOCH[12] - STEP[100]
# Generator_loss:0.6313
# L1_loss:0.1517
# Discriminator_loss:1.1560
#
# EPOCH[12] - STEP[120]
# Generator_loss:1.2102
# L1_loss:0.1998
# Discriminator_loss:1.1027
#
# EPOCH[12] - STEP[140]
# Generator_loss:1.2810
# L1_loss:0.1404
# Discriminator_loss:0.9382
#
# EPOCH[12] - STEP[160]
# Generator_loss:2.4117
# L1_loss:0.1220
# Discriminator_loss:2.3804
#
# EPOCH[12] - STEP[180]
# Generator_loss:0.5554
# L1_loss:0.1625
# Discriminator_loss:1.1792
#
# EPOCH[12] - STEP[200]
# Generator_loss:0.9607
# L1_loss:0.1590
# Discriminator_loss:1.1724
#
# EPOCH[12] - STEP[220]
# Generator_loss:1.2795
# L1_loss:0.1606
# Discriminator_loss:1.1703
#
# EPOCH[12] - STEP[240]
# Generator_loss:1.3772
# L1_loss:0.1724
# Discriminator_loss:0.6359
#
# EPOCH[13] - STEP[20]
# Generator_loss:2.3619
# L1_loss:0.1795
# Discriminator_loss:0.6039
#
# EPOCH[13] - STEP[40]
# Generator_loss:2.1277
# L1_loss:0.1652
# Discriminator_loss:1.3305
#
# EPOCH[13] - STEP[60]
# Generator_loss:0.9709
# L1_loss:0.1528
# Discriminator_loss:0.6752
#
# EPOCH[13] - STEP[80]
# Generator_loss:0.3585
# L1_loss:0.1676
# Discriminator_loss:1.7855
#
# EPOCH[13] - STEP[100]
# Generator_loss:1.7113
# L1_loss:0.2231
# Discriminator_loss:0.2819
#
# EPOCH[13] - STEP[120]
# Generator_loss:1.1855
# L1_loss:0.1575
# Discriminator_loss:2.0354
#
# EPOCH[13] - STEP[140]
# Generator_loss:0.9175
# L1_loss:0.1956
# Discriminator_loss:0.7981
#
# EPOCH[13] - STEP[160]
# Generator_loss:1.0791
# L1_loss:0.1783
# Discriminator_loss:0.8256
#
# EPOCH[13] - STEP[180]
# Generator_loss:0.9503
# L1_loss:0.1679
# Discriminator_loss:0.7183
#
# EPOCH[13] - STEP[200]
# Generator_loss:1.9692
# L1_loss:0.1750
# Discriminator_loss:0.6725
#
# EPOCH[13] - STEP[220]
# Generator_loss:2.3821
# L1_loss:0.2022
# Discriminator_loss:0.2942
#
# EPOCH[13] - STEP[240]
# Generator_loss:0.5631
# L1_loss:0.2265
# Discriminator_loss:1.0088
#
# EPOCH[14] - STEP[20]
# Generator_loss:1.4546
# L1_loss:0.1916
# Discriminator_loss:1.1247
#
# EPOCH[14] - STEP[40]
# Generator_loss:2.3845
# L1_loss:0.1537
# Discriminator_loss:1.1499
#
# EPOCH[14] - STEP[60]
# Generator_loss:0.5691
# L1_loss:0.1370
# Discriminator_loss:1.8581
#
# EPOCH[14] - STEP[80]
# Generator_loss:1.1015
# L1_loss:0.1679
# Discriminator_loss:0.7005
#
# EPOCH[14] - STEP[100]
# Generator_loss:2.3838
# L1_loss:0.1618
# Discriminator_loss:0.5571
#
# EPOCH[14] - STEP[120]
# Generator_loss:0.9264
# L1_loss:0.2045
# Discriminator_loss:0.6445
#
# EPOCH[14] - STEP[140]
# Generator_loss:1.2844
# L1_loss:0.1521
# Discriminator_loss:0.8571
#
# EPOCH[14] - STEP[160]
# Generator_loss:1.3325
# L1_loss:0.1833
# Discriminator_loss:0.5843
#
# EPOCH[14] - STEP[180]
# Generator_loss:0.9936
# L1_loss:0.2008
# Discriminator_loss:0.6202
#
# EPOCH[14] - STEP[200]
# Generator_loss:1.5359
# L1_loss:0.1507
# Discriminator_loss:1.0654
#
# EPOCH[14] - STEP[220]
# Generator_loss:0.8470
# L1_loss:0.2089
# Discriminator_loss:0.7156
#
# EPOCH[14] - STEP[240]
# Generator_loss:1.7090
# L1_loss:0.1720
# Discriminator_loss:0.4154
# EPOCH[15] - STEP[20]
# Generator_loss:1.1260
# L1_loss:0.2068
# Discriminator_loss:0.7331
#
# EPOCH[15] - STEP[40]
# Generator_loss:1.5106
# L1_loss:0.1579
# Discriminator_loss:0.4904
#
# EPOCH[15] - STEP[60]
# Generator_loss:1.5545
# L1_loss:0.1588
# Discriminator_loss:0.4237
#
# EPOCH[15] - STEP[80]
# Generator_loss:0.8455
# L1_loss:0.1860
# Discriminator_loss:0.8267
#
# EPOCH[15] - STEP[100]
# Generator_loss:2.0706
# L1_loss:0.1463
# Discriminator_loss:1.5985
#
# EPOCH[15] - STEP[120]
# Generator_loss:2.0530
# L1_loss:0.1717
# Discriminator_loss:0.4907
#
# EPOCH[15] - STEP[140]
# Generator_loss:2.0876
# L1_loss:0.1809
# Discriminator_loss:0.5532
#
# EPOCH[15] - STEP[160]
# Generator_loss:1.6172
# L1_loss:0.2474
# Discriminator_loss:0.2726
#
# EPOCH[15] - STEP[180]
# Generator_loss:2.3898
# L1_loss:0.1570
# Discriminator_loss:1.0598
#
# EPOCH[15] - STEP[200]
# Generator_loss:2.0736
# L1_loss:0.1646
# Discriminator_loss:0.5163
#
# EPOCH[15] - STEP[220]
# Generator_loss:0.2930
# L1_loss:0.1647
# Discriminator_loss:1.8839
#
# EPOCH[15] - STEP[240]
# Generator_loss:0.6094
# L1_loss:0.1970
# Discriminator_loss:0.8620
#
# EPOCH[16] - STEP[20]
# Generator_loss:1.0778
# L1_loss:0.1530
# Discriminator_loss:1.5228
#
# EPOCH[16] - STEP[40]
# Generator_loss:1.1645
# L1_loss:0.1538
# Discriminator_loss:1.0162
#
# EPOCH[16] - STEP[60]
# Generator_loss:0.5305
# L1_loss:0.1486
# Discriminator_loss:1.8611
#
# EPOCH[16] - STEP[80]
# Generator_loss:2.2704
# L1_loss:0.1775
# Discriminator_loss:0.8397
#
# EPOCH[16] - STEP[100]
# Generator_loss:0.8018
# L1_loss:0.1597
# Discriminator_loss:1.0143
#
# EPOCH[16] - STEP[120]
# Generator_loss:1.0729
# L1_loss:0.1385
# Discriminator_loss:1.1798
#
# EPOCH[16] - STEP[140]
# Generator_loss:1.5089
# L1_loss:0.1496
# Discriminator_loss:1.8112
#
# EPOCH[16] - STEP[160]
# Generator_loss:2.1800
# L1_loss:0.1551
# Discriminator_loss:1.0938
#
# EPOCH[16] - STEP[180]
# Generator_loss:1.2610
# L1_loss:0.1470
# Discriminator_loss:0.8272
#
# EPOCH[16] - STEP[200]
# Generator_loss:2.0217
# L1_loss:0.1800
# Discriminator_loss:0.4254
#
# EPOCH[16] - STEP[220]
# Generator_loss:1.4991
# L1_loss:0.1547
# Discriminator_loss:1.5564
#
# EPOCH[16] - STEP[240]
# Generator_loss:1.0163
# L1_loss:0.1423
# Discriminator_loss:0.9058
#
# EPOCH[17] - STEP[20]
# Generator_loss:0.9173
# L1_loss:0.2085
# Discriminator_loss:0.5971
#
# EPOCH[17] - STEP[40]
# Generator_loss:0.4662
# L1_loss:0.1594
# Discriminator_loss:1.3067
#
# EPOCH[17] - STEP[60]
# Generator_loss:1.3466
# L1_loss:0.1671
# Discriminator_loss:0.6891
#
# EPOCH[17] - STEP[80]
# Generator_loss:1.0379
# L1_loss:0.1762
# Discriminator_loss:0.6547
#
# EPOCH[17] - STEP[100]
# Generator_loss:2.6780
# L1_loss:0.1611
# Discriminator_loss:1.1083
#
# EPOCH[17] - STEP[120]
# Generator_loss:2.1529
# L1_loss:0.1514
# Discriminator_loss:1.0381
#
# EPOCH[17] - STEP[140]
# Generator_loss:0.9031
# L1_loss:0.1751
# Discriminator_loss:2.4857
#
# EPOCH[17] - STEP[160]
# Generator_loss:0.9940
# L1_loss:0.1679
# Discriminator_loss:0.9675
#
# EPOCH[17] - STEP[180]
# Generator_loss:0.9303
# L1_loss:0.2231
# Discriminator_loss:0.5790
#
# EPOCH[17] - STEP[200]
# Generator_loss:1.4378
# L1_loss:0.2236
# Discriminator_loss:0.3452
#
# EPOCH[17] - STEP[220]
# Generator_loss:1.0383
# L1_loss:0.1522
# Discriminator_loss:1.1811
#
# EPOCH[17] - STEP[240]
# Generator_loss:1.6904
# L1_loss:0.1631
# Discriminator_loss:1.9556
#
# EPOCH[18] - STEP[20]
# Generator_loss:2.2454
# L1_loss:0.1788
# Discriminator_loss:0.5701
#
# EPOCH[18] - STEP[40]
# Generator_loss:1.2658
# L1_loss:0.1591
# Discriminator_loss:0.7655
#
# EPOCH[18] - STEP[60]
# Generator_loss:0.9724
# L1_loss:0.1620
# Discriminator_loss:0.8186
#
# EPOCH[18] - STEP[80]
# Generator_loss:1.5675
# L1_loss:0.1588
# Discriminator_loss:0.7585
#
# EPOCH[18] - STEP[100]
# Generator_loss:1.5187
# L1_loss:0.1296
# Discriminator_loss:2.1399
#
# EPOCH[18] - STEP[120]
# Generator_loss:1.2420
# L1_loss:0.1765
# Discriminator_loss:0.7110
#
# EPOCH[18] - STEP[140]
# Generator_loss:1.0001
# L1_loss:0.1665
# Discriminator_loss:0.8010
#
# EPOCH[18] - STEP[160]
# Generator_loss:1.0286
# L1_loss:0.1773
# Discriminator_loss:0.8440
#
# EPOCH[18] - STEP[180]
# Generator_loss:2.0778
# L1_loss:0.1537
# Discriminator_loss:0.5524
#
# EPOCH[18] - STEP[200]
# Generator_loss:1.0026
# L1_loss:0.1790
# Discriminator_loss:0.8145
#
# EPOCH[18] - STEP[220]
# Generator_loss:2.4652
# L1_loss:0.2099
# Discriminator_loss:0.6187
#
# EPOCH[18] - STEP[240]
# Generator_loss:0.8874
# L1_loss:0.1766
# Discriminator_loss:0.7613
#
# EPOCH[19] - STEP[20]
# Generator_loss:1.5648
# L1_loss:0.1579
# Discriminator_loss:0.6170
#
# EPOCH[19] - STEP[40]
# Generator_loss:2.7182
# L1_loss:0.1756
# Discriminator_loss:0.2798
#
# EPOCH[19] - STEP[60]
# Generator_loss:1.0830
# L1_loss:0.1355
# Discriminator_loss:1.4519
#
# EPOCH[19] - STEP[80]
# Generator_loss:2.0547
# L1_loss:0.1786
# Discriminator_loss:0.5053
#
# EPOCH[19] - STEP[100]
# Generator_loss:0.4980
# L1_loss:0.1765
# Discriminator_loss:1.6194
#
# EPOCH[19] - STEP[120]
# Generator_loss:0.3349
# L1_loss:0.1925
# Discriminator_loss:1.4412
#
# EPOCH[19] - STEP[140]
# Generator_loss:2.4397
# L1_loss:0.1848
# Discriminator_loss:0.2175
#
# EPOCH[19] - STEP[160]
# Generator_loss:1.5986
# L1_loss:0.1534
# Discriminator_loss:1.0724
# EPOCH[19] - STEP[180]
# Generator_loss:1.9826
# L1_loss:0.1727
# Discriminator_loss:0.9382
#
# EPOCH[19] - STEP[200]
# Generator_loss:0.3052
# L1_loss:0.1565
# Discriminator_loss:1.8821
#
# EPOCH[19] - STEP[220]
# Generator_loss:1.4898
# L1_loss:0.1555
# Discriminator_loss:1.8108
#
# EPOCH[19] - STEP[240]
# Generator_loss:1.8331
# L1_loss:0.2014
# Discriminator_loss:0.3008
#
# EPOCH[20] - STEP[20]
# Generator_loss:1.2504
# L1_loss:0.1648
# Discriminator_loss:1.4649
#
# EPOCH[20] - STEP[40]
# Generator_loss:0.1489
# L1_loss:0.1617
# Discriminator_loss:2.2951
#
# EPOCH[20] - STEP[60]
# Generator_loss:1.9085
# L1_loss:0.1639
# Discriminator_loss:0.6417
#
# EPOCH[20] - STEP[80]
# Generator_loss:1.4425
# L1_loss:0.1465
# Discriminator_loss:1.2143
#
# EPOCH[20] - STEP[100]
# Generator_loss:1.8166
# L1_loss:0.1582
# Discriminator_loss:0.6981
#
# EPOCH[20] - STEP[120]
# Generator_loss:1.1296
# L1_loss:0.2033
# Discriminator_loss:0.4862
#
# EPOCH[20] - STEP[140]
# Generator_loss:2.2930
# L1_loss:0.1846
# Discriminator_loss:0.8802
#
# EPOCH[20] - STEP[160]
# Generator_loss:2.6509
# L1_loss:0.1302
# Discriminator_loss:3.1330
#
# EPOCH[20] - STEP[180]
# Generator_loss:1.1992
# L1_loss:0.1477
# Discriminator_loss:1.0571
#
# EPOCH[20] - STEP[200]
# Generator_loss:0.4734
# L1_loss:0.1757
# Discriminator_loss:1.3600
#
# EPOCH[20] - STEP[220]
# Generator_loss:0.6939
# L1_loss:0.1815
# Discriminator_loss:1.3029
#
# EPOCH[20] - STEP[240]
# Generator_loss:0.9736
# L1_loss:0.1648
# Discriminator_loss:0.8383
#
# EPOCH[21] - STEP[20]
# Generator_loss:0.4823
# L1_loss:0.1799
# Discriminator_loss:1.1235
#
# EPOCH[21] - STEP[40]
# Generator_loss:2.2548
# L1_loss:0.1458
# Discriminator_loss:1.4873
#
# EPOCH[21] - STEP[60]
# Generator_loss:0.7506
# L1_loss:0.1851
# Discriminator_loss:0.7710
#
# EPOCH[21] - STEP[80]
# Generator_loss:1.0808
# L1_loss:0.1444
# Discriminator_loss:1.7381
#
# EPOCH[21] - STEP[100]
# Generator_loss:2.0204
# L1_loss:0.1671
# Discriminator_loss:0.3462
#
# EPOCH[21] - STEP[120]
# Generator_loss:1.9096
# L1_loss:0.1775
# Discriminator_loss:0.5030
#
# EPOCH[21] - STEP[140]
# Generator_loss:1.4228
# L1_loss:0.1695
# Discriminator_loss:0.7846
#
# EPOCH[21] - STEP[160]
# Generator_loss:1.3572
# L1_loss:0.1579
# Discriminator_loss:0.4323
#
# EPOCH[21] - STEP[180]
# Generator_loss:1.9453
# L1_loss:0.1753
# Discriminator_loss:0.3229
#
# EPOCH[21] - STEP[200]
# Generator_loss:1.0783
# L1_loss:0.1597
# Discriminator_loss:2.4042
#
# EPOCH[21] - STEP[220]
# Generator_loss:0.7270
# L1_loss:0.1766
# Discriminator_loss:0.9514
#
# EPOCH[21] - STEP[240]
# Generator_loss:1.9139
# L1_loss:0.1860
# Discriminator_loss:0.2409
#
# EPOCH[22] - STEP[20]
# Generator_loss:0.8123
# L1_loss:0.2348
# Discriminator_loss:0.7158
#
# EPOCH[22] - STEP[40]
# Generator_loss:1.7347
# L1_loss:0.1631
# Discriminator_loss:1.0974
#
# EPOCH[22] - STEP[60]
# Generator_loss:1.0574
# L1_loss:0.1647
# Discriminator_loss:0.6656
#
# EPOCH[22] - STEP[80]
# Generator_loss:1.4024
# L1_loss:0.1649
# Discriminator_loss:0.7924
#
# EPOCH[22] - STEP[100]
# Generator_loss:1.4809
# L1_loss:0.1469
# Discriminator_loss:0.9345
#
# EPOCH[22] - STEP[120]
# Generator_loss:2.4332
# L1_loss:0.1882
# Discriminator_loss:0.3523
#
# EPOCH[22] - STEP[140]
# Generator_loss:0.8438
# L1_loss:0.1638
# Discriminator_loss:0.6299
#
# EPOCH[22] - STEP[160]
# Generator_loss:1.0467
# L1_loss:0.1353
# Discriminator_loss:2.0776
#
# EPOCH[22] - STEP[180]
# Generator_loss:1.1591
# L1_loss:0.1601
# Discriminator_loss:1.0583
#
# EPOCH[22] - STEP[200]
# Generator_loss:1.5680
# L1_loss:0.1519
# Discriminator_loss:0.6894
#
# EPOCH[22] - STEP[220]
# Generator_loss:0.3296
# L1_loss:0.1334
# Discriminator_loss:2.0747
#
# EPOCH[22] - STEP[240]
# Generator_loss:1.3181
# L1_loss:0.1723
# Discriminator_loss:1.4252
#
# EPOCH[23] - STEP[20]
# Generator_loss:0.8899
# L1_loss:0.1661
# Discriminator_loss:0.7393
#
# EPOCH[23] - STEP[40]
# Generator_loss:1.1390
# L1_loss:0.1592
# Discriminator_loss:0.7098
#
# EPOCH[23] - STEP[60]
# Generator_loss:1.9013
# L1_loss:0.1403
# Discriminator_loss:1.4204
#
# EPOCH[23] - STEP[80]
# Generator_loss:1.7071
# L1_loss:0.1496
# Discriminator_loss:1.2758
#
# EPOCH[23] - STEP[100]
# Generator_loss:2.9170
# L1_loss:0.1446
# Discriminator_loss:1.6328
#
# EPOCH[23] - STEP[120]
# Generator_loss:1.1775
# L1_loss:0.1600
# Discriminator_loss:0.6458
#
# EPOCH[23] - STEP[140]
# Generator_loss:2.0986
# L1_loss:0.1648
# Discriminator_loss:0.4475
#
# EPOCH[23] - STEP[160]
# Generator_loss:1.4334
# L1_loss:0.1770
# Discriminator_loss:0.5508
#
# EPOCH[23] - STEP[180]
# Generator_loss:0.7615
# L1_loss:0.1899
# Discriminator_loss:0.8704
#
# EPOCH[23] - STEP[200]
# Generator_loss:0.5431
# L1_loss:0.1706
# Discriminator_loss:1.3222
#
# EPOCH[23] - STEP[220]
# Generator_loss:0.6953
# L1_loss:0.1769
# Discriminator_loss:0.9766
#
# EPOCH[23] - STEP[240]
# Generator_loss:0.9948
# L1_loss:0.1547
# Discriminator_loss:1.2560
#
# EPOCH[24] - STEP[20]
# Generator_loss:1.0718
# L1_loss:0.1574
# Discriminator_loss:0.7668
#
# EPOCH[24] - STEP[40]
# Generator_loss:0.7133
# L1_loss:0.1833
# Discriminator_loss:0.7814
#
# EPOCH[24] - STEP[60]
# Generator_loss:2.0608
# L1_loss:0.1475
# Discriminator_loss:1.6427
#
# EPOCH[24] - STEP[80]
# Generator_loss:1.4929
# L1_loss:0.1640
# Discriminator_loss:1.6891
# EPOCH[24] - STEP[100]
# Generator_loss:0.9445
# L1_loss:0.1564
# Discriminator_loss:1.2667
#
# EPOCH[24] - STEP[120]
# Generator_loss:0.4100
# L1_loss:0.1882
# Discriminator_loss:1.5735
#
# EPOCH[24] - STEP[140]
# Generator_loss:1.8753
# L1_loss:0.1689
# Discriminator_loss:0.2937
#
# EPOCH[24] - STEP[160]
# Generator_loss:1.4436
# L1_loss:0.1599
# Discriminator_loss:1.7521
#
# EPOCH[24] - STEP[180]
# Generator_loss:1.2593
# L1_loss:0.1815
# Discriminator_loss:0.4662
#
# EPOCH[24] - STEP[200]
# Generator_loss:0.3970
# L1_loss:0.1741
# Discriminator_loss:1.2720
#
# EPOCH[24] - STEP[220]
# Generator_loss:0.7000
# L1_loss:0.1723
# Discriminator_loss:1.8899
#
# EPOCH[24] - STEP[240]
# Generator_loss:1.2916
# L1_loss:0.1728
# Discriminator_loss:1.1516
#
# EPOCH[25] - STEP[20]
# Generator_loss:1.6318
# L1_loss:0.1225
# Discriminator_loss:1.5341
#
# EPOCH[25] - STEP[40]
# Generator_loss:0.9345
# L1_loss:0.1474
# Discriminator_loss:0.8902
#
# EPOCH[25] - STEP[60]
# Generator_loss:1.2192
# L1_loss:0.1668
# Discriminator_loss:0.4378
#
# EPOCH[25] - STEP[80]
# Generator_loss:1.0071
# L1_loss:0.1922
# Discriminator_loss:0.5962
#
# EPOCH[25] - STEP[100]
# Generator_loss:2.0956
# L1_loss:0.1464
# Discriminator_loss:1.3876
#
# EPOCH[25] - STEP[120]
# Generator_loss:0.6355
# L1_loss:0.1767
# Discriminator_loss:0.9057
#
# EPOCH[25] - STEP[140]
# Generator_loss:0.9914
# L1_loss:0.1986
# Discriminator_loss:0.5839
#
# EPOCH[25] - STEP[160]
# Generator_loss:0.9908
# L1_loss:0.1710
# Discriminator_loss:1.1455
#
# EPOCH[25] - STEP[180]
# Generator_loss:2.0190
# L1_loss:0.1712
# Discriminator_loss:0.6889
#
# EPOCH[25] - STEP[200]
# Generator_loss:1.2481
# L1_loss:0.1562
# Discriminator_loss:0.7892
#
# EPOCH[25] - STEP[220]
# Generator_loss:1.3113
# L1_loss:0.1567
# Discriminator_loss:0.8501
#
# EPOCH[25] - STEP[240]
# Generator_loss:1.0020
# L1_loss:0.1621
# Discriminator_loss:0.8255
#
# EPOCH[26] - STEP[20]
# Generator_loss:1.0828
# L1_loss:0.1651
# Discriminator_loss:0.6418
#
# EPOCH[26] - STEP[40]
# Generator_loss:0.6872
# L1_loss:0.1427
# Discriminator_loss:1.2764
#
# EPOCH[26] - STEP[60]
# Generator_loss:1.7996
# L1_loss:0.1438
# Discriminator_loss:1.1676
#
# EPOCH[26] - STEP[80]
# Generator_loss:1.2165
# L1_loss:0.1817
# Discriminator_loss:0.4959
#
# EPOCH[26] - STEP[100]
# Generator_loss:1.0049
# L1_loss:0.1593
# Discriminator_loss:0.6894
#
# EPOCH[26] - STEP[120]
# Generator_loss:1.9378
# L1_loss:0.1342
# Discriminator_loss:1.5227
#
# EPOCH[26] - STEP[140]
# Generator_loss:2.6663
# L1_loss:0.1971
# Discriminator_loss:0.3325
#
# EPOCH[26] - STEP[160]
# Generator_loss:0.1483
# L1_loss:0.1425
# Discriminator_loss:2.3989
#
# EPOCH[26] - STEP[180]
# Generator_loss:1.5020
# L1_loss:0.1500
# Discriminator_loss:0.6528
#
# EPOCH[26] - STEP[200]
# Generator_loss:0.6714
# L1_loss:0.1505
# Discriminator_loss:1.6471
#
# EPOCH[26] - STEP[220]
# Generator_loss:0.4661
# L1_loss:0.1714
# Discriminator_loss:1.3885
#
# EPOCH[26] - STEP[240]
# Generator_loss:1.4646
# L1_loss:0.1580
# Discriminator_loss:0.5347
#
# EPOCH[27] - STEP[20]
# Generator_loss:1.3122
# L1_loss:0.1832
# Discriminator_loss:0.6260
#
# EPOCH[27] - STEP[40]
# Generator_loss:1.9094
# L1_loss:0.1698
# Discriminator_loss:0.5767
#
# EPOCH[27] - STEP[60]
# Generator_loss:2.0141
# L1_loss:0.1470
# Discriminator_loss:0.3845
#
# EPOCH[27] - STEP[80]
# Generator_loss:0.7874
# L1_loss:0.1794
# Discriminator_loss:1.8276
#
# EPOCH[27] - STEP[100]
# Generator_loss:1.8860
# L1_loss:0.1627
# Discriminator_loss:0.8880
#
# EPOCH[27] - STEP[120]
# Generator_loss:2.5901
# L1_loss:0.1811
# Discriminator_loss:1.3415
#
# EPOCH[27] - STEP[140]
# Generator_loss:0.8692
# L1_loss:0.1874
# Discriminator_loss:1.3241
#
# EPOCH[27] - STEP[160]
# Generator_loss:1.0860
# L1_loss:0.2118
# Discriminator_loss:0.5020
#
# EPOCH[27] - STEP[180]
# Generator_loss:1.2639
# L1_loss:0.1880
# Discriminator_loss:0.6173
#
# EPOCH[27] - STEP[200]
# Generator_loss:1.7897
# L1_loss:0.1690
# Discriminator_loss:0.2598
#
# EPOCH[27] - STEP[220]
# Generator_loss:2.5450
# L1_loss:0.1922
# Discriminator_loss:0.2419
#
# EPOCH[27] - STEP[240]
# Generator_loss:2.2547
# ...
# L1_loss:0.1332
# Discriminator_loss:1.6554
#
# EPOCH[42] - STEP[40]
# Generator_loss:1.3836
# L1_loss:0.1708
# Discriminator_loss:0.3851
#
# EPOCH[42] - STEP[60]
# Generator_loss:0.7187
# L1_loss:0.1614
# Discriminator_loss:1.0434
#
# EPOCH[42] - STEP[80]
# Generator_loss:1.3930
# L1_loss:0.1283
# Discriminator_loss:0.6258
#
# EPOCH[42] - STEP[100]
# Generator_loss:1.6957
# L1_loss:0.1691
# Discriminator_loss:0.9187
#
# EPOCH[42] - STEP[120]
# Generator_loss:0.9771
# L1_loss:0.1599
# Discriminator_loss:0.6272
#
# EPOCH[42] - STEP[140]
# Generator_loss:1.7631
# L1_loss:0.1444
# Discriminator_loss:0.8855
#
# EPOCH[42] - STEP[160]
# Generator_loss:2.7912
# L1_loss:0.1469
# Discriminator_loss:0.7065
#
# EPOCH[42] - STEP[180]
# Generator_loss:0.8781
# L1_loss:0.1623
# Discriminator_loss:0.6244
#
# EPOCH[42] - STEP[200]
# Generator_loss:1.6828
# L1_loss:0.1659
# Discriminator_loss:0.3989
#
# EPOCH[42] - STEP[220]
# Generator_loss:2.5561
# L1_loss:0.1959
# Discriminator_loss:0.9857
#
# EPOCH[42] - STEP[240]
# Generator_loss:1.3054
# L1_loss:0.1473
# Discriminator_loss:1.1404
# EPOCH[43] - STEP[20]
# Generator_loss:2.5981
# L1_loss:0.1471
# Discriminator_loss:1.2111
#
# EPOCH[43] - STEP[40]
# Generator_loss:1.7643
# L1_loss:0.1616
# Discriminator_loss:0.5342
#
# EPOCH[43] - STEP[60]
# Generator_loss:2.2610
# L1_loss:0.1738
# Discriminator_loss:1.0458
#
# EPOCH[43] - STEP[80]
# Generator_loss:1.7068
# L1_loss:0.1574
# Discriminator_loss:0.6942
#
# EPOCH[43] - STEP[100]
# Generator_loss:1.0623
# L1_loss:0.1660
# Discriminator_loss:0.6855
#
# EPOCH[43] - STEP[120]
# Generator_loss:0.5360
# L1_loss:0.1715
# Discriminator_loss:1.1309
#
# EPOCH[43] - STEP[140]
# Generator_loss:1.5003
# L1_loss:0.1580
# Discriminator_loss:0.3994
#
# EPOCH[43] - STEP[160]
# Generator_loss:1.6521
# L1_loss:0.1947
# Discriminator_loss:0.4187
#
# EPOCH[43] - STEP[180]
# Generator_loss:1.1699
# L1_loss:0.1624
# Discriminator_loss:0.5668
#
# EPOCH[43] - STEP[200]
# Generator_loss:2.1731
# L1_loss:0.1574
# Discriminator_loss:1.0782
#
# EPOCH[43] - STEP[220]
# Generator_loss:0.4849
# L1_loss:0.1740
# Discriminator_loss:1.1622
#
# EPOCH[43] - STEP[240]
# Generator_loss:1.0860
# L1_loss:0.1644
# Discriminator_loss:1.2564
#
# EPOCH[44] - STEP[20]
# Generator_loss:1.6373
# L1_loss:0.1741
# Discriminator_loss:0.8763
#
# EPOCH[44] - STEP[40]
# Generator_loss:1.1776
# L1_loss:0.1528
# Discriminator_loss:0.7975
#
# EPOCH[44] - STEP[60]
# Generator_loss:0.7757
# L1_loss:0.1690
# Discriminator_loss:0.9366
#
# EPOCH[44] - STEP[80]
# Generator_loss:0.6603
# L1_loss:0.1498
# Discriminator_loss:1.2403
#
# EPOCH[44] - STEP[100]
# Generator_loss:1.2692
# L1_loss:0.1637
# Discriminator_loss:0.8532
#
# EPOCH[44] - STEP[120]
# Generator_loss:0.6286
# L1_loss:0.1661
# Discriminator_loss:1.0765
#
# EPOCH[44] - STEP[140]
# Generator_loss:0.5578
# L1_loss:0.1742
# Discriminator_loss:1.1533
#
# EPOCH[44] - STEP[160]
# Generator_loss:1.6955
# L1_loss:0.1916
# Discriminator_loss:0.3058
#
# EPOCH[44] - STEP[180]
# Generator_loss:1.5740
# L1_loss:0.1817
# Discriminator_loss:0.3493
#
# EPOCH[44] - STEP[200]
# Generator_loss:2.6325
# L1_loss:0.1480
# Discriminator_loss:1.2266
#
# EPOCH[44] - STEP[220]
# Generator_loss:1.5208
# L1_loss:0.1530
# Discriminator_loss:2.2387
#
# EPOCH[44] - STEP[240]
# Generator_loss:0.4325
# L1_loss:0.1679
# Discriminator_loss:1.2042
#
# EPOCH[45] - STEP[20]
# Generator_loss:0.1763
# L1_loss:0.1433
# Discriminator_loss:2.1837
#
# EPOCH[45] - STEP[40]
# Generator_loss:1.2366
# L1_loss:0.1876
# Discriminator_loss:0.6504
#
# EPOCH[45] - STEP[60]
# Generator_loss:1.6337
# L1_loss:0.1531
# Discriminator_loss:0.4209
#
# EPOCH[45] - STEP[80]
# Generator_loss:0.5480
# L1_loss:0.1748
# Discriminator_loss:0.9861
#
# EPOCH[45] - STEP[100]
# Generator_loss:0.9225
# L1_loss:0.1633
# Discriminator_loss:0.8983
#
# EPOCH[45] - STEP[120]
# Generator_loss:1.6804
# L1_loss:0.1705
# Discriminator_loss:0.4981
#
# EPOCH[45] - STEP[140]
# Generator_loss:0.6587
# L1_loss:0.1651
# Discriminator_loss:0.9488
#
# EPOCH[45] - STEP[160]
# Generator_loss:0.6071
# L1_loss:0.1451
# Discriminator_loss:1.0911
#
# EPOCH[45] - STEP[180]
# Generator_loss:1.0917
# L1_loss:0.1476
# Discriminator_loss:1.0425
#
# EPOCH[45] - STEP[200]
# Generator_loss:2.4653
# L1_loss:0.1725
# Discriminator_loss:0.3107
#
# EPOCH[45] - STEP[220]
# Generator_loss:0.4774
# L1_loss:0.1870
# Discriminator_loss:1.2109
#
# EPOCH[45] - STEP[240]
# Generator_loss:0.6743
# L1_loss:0.1719
# Discriminator_loss:1.1589
#
# EPOCH[46] - STEP[20]
# Generator_loss:1.7181
# L1_loss:0.1834
# Discriminator_loss:0.2890
#
# EPOCH[46] - STEP[40]
# Generator_loss:1.0263
# L1_loss:0.1671
# Discriminator_loss:0.8151
#
# EPOCH[46] - STEP[60]
# Generator_loss:1.2634
# L1_loss:0.2233
# Discriminator_loss:0.4795
#
# EPOCH[46] - STEP[80]
# Generator_loss:0.4266
# L1_loss:0.1736
# Discriminator_loss:1.3559
#
# EPOCH[46] - STEP[100]
# Generator_loss:0.2850
# L1_loss:0.1643
# Discriminator_loss:1.7842
#
# EPOCH[46] - STEP[120]
# Generator_loss:1.4340
# L1_loss:0.1774
# Discriminator_loss:1.4137
#
# EPOCH[46] - STEP[140]
# Generator_loss:1.3971
# L1_loss:0.1535
# Discriminator_loss:0.4766
#
# EPOCH[46] - STEP[160]
# Generator_loss:0.6146
# L1_loss:0.1503
# Discriminator_loss:1.1082
#
# EPOCH[46] - STEP[180]
# Generator_loss:2.3239
# L1_loss:0.1407
# Discriminator_loss:0.8056
#
# EPOCH[46] - STEP[200]
# Generator_loss:2.4820
# L1_loss:0.1733
# Discriminator_loss:0.3478
#
# EPOCH[46] - STEP[220]
# Generator_loss:0.5189
# L1_loss:0.1910
# Discriminator_loss:1.3179
#
# EPOCH[46] - STEP[240]
# Generator_loss:0.5549
# L1_loss:0.1599
# Discriminator_loss:1.1707
#
# EPOCH[47] - STEP[20]
# Generator_loss:0.7563
# L1_loss:0.1897
# Discriminator_loss:1.5613
#
# EPOCH[47] - STEP[40]
# Generator_loss:1.8799
# L1_loss:0.1770
# Discriminator_loss:0.3779
#
# EPOCH[47] - STEP[60]
# Generator_loss:1.4623
# L1_loss:0.1873
# Discriminator_loss:0.8961
#
# EPOCH[47] - STEP[80]
# Generator_loss:0.1497
# L1_loss:0.1984
# Discriminator_loss:2.1719
#
# EPOCH[47] - STEP[100]
# Generator_loss:1.2852
# L1_loss:0.1628
# Discriminator_loss:0.8976
#
# EPOCH[47] - STEP[120]
# Generator_loss:1.2704
# L1_loss:0.1929
# Discriminator_loss:0.5853
#
# EPOCH[47] - STEP[140]
# Generator_loss:1.4369
# L1_loss:0.2029
# Discriminator_loss:1.2270
#
# EPOCH[47] - STEP[160]
# Generator_loss:2.2180
# L1_loss:0.2002
# Discriminator_loss:2.5706
# EPOCH[47] - STEP[180]
# Generator_loss:0.6462
# L1_loss:0.1449
# Discriminator_loss:1.0988
#
# EPOCH[47] - STEP[200]
# Generator_loss:0.8223
# L1_loss:0.1637
# Discriminator_loss:0.9281
#
# EPOCH[47] - STEP[220]
# Generator_loss:1.1634
# L1_loss:0.1416
# Discriminator_loss:1.3217
#
# EPOCH[47] - STEP[240]
# Generator_loss:1.2586
# L1_loss:0.1483
# Discriminator_loss:1.5896
#
# EPOCH[48] - STEP[20]
# Generator_loss:0.8672
# L1_loss:0.1895
# Discriminator_loss:0.6977
#
# EPOCH[48] - STEP[40]
# Generator_loss:1.2500
# L1_loss:0.1716
# Discriminator_loss:0.5828
#
# EPOCH[48] - STEP[60]
# Generator_loss:0.4382
# L1_loss:0.1664
# Discriminator_loss:1.3551
#
# EPOCH[48] - STEP[80]
# Generator_loss:1.5477
# L1_loss:0.1579
# Discriminator_loss:0.6147
#
# EPOCH[48] - STEP[100]
# Generator_loss:0.4558
# L1_loss:0.1286
# Discriminator_loss:1.6974
#
# EPOCH[48] - STEP[120]
# Generator_loss:2.0660
# L1_loss:0.1671
# Discriminator_loss:0.2438
#
# EPOCH[48] - STEP[140]
# Generator_loss:0.5211
# L1_loss:0.1571
# Discriminator_loss:1.1950
#
# EPOCH[48] - STEP[160]
# Generator_loss:1.6644
# L1_loss:0.1818
# Discriminator_loss:0.6968
#
# EPOCH[48] - STEP[180]
# Generator_loss:0.5398
# L1_loss:0.1886
# Discriminator_loss:1.0983
#
# EPOCH[48] - STEP[200]
# Generator_loss:1.0100
# L1_loss:0.1571
# Discriminator_loss:0.6499
#
# EPOCH[48] - STEP[220]
# Generator_loss:0.5025
# L1_loss:0.1715
# Discriminator_loss:1.0492
#
# EPOCH[48] - STEP[240]
# Generator_loss:0.9370
# L1_loss:0.1619
# Discriminator_loss:1.3704
#
# EPOCH[49] - STEP[20]
# Generator_loss:1.0955
# L1_loss:0.1437
# Discriminator_loss:1.5471
#
# EPOCH[49] - STEP[40]
# Generator_loss:1.7393
# L1_loss:0.1474
# Discriminator_loss:0.6463
#
# EPOCH[49] - STEP[60]
# Generator_loss:0.7503
# L1_loss:0.1950
# Discriminator_loss:0.8609
#
# EPOCH[49] - STEP[80]
# Generator_loss:0.6772
# L1_loss:0.1595
# Discriminator_loss:0.9245
#
# EPOCH[49] - STEP[100]
# Generator_loss:0.9557
# L1_loss:0.1542
# Discriminator_loss:0.8263
#
# EPOCH[49] - STEP[120]
# Generator_loss:1.0630
# L1_loss:0.1672
# Discriminator_loss:0.5447
#
# EPOCH[49] - STEP[140]
# Generator_loss:1.9049
# L1_loss:0.1379
# Discriminator_loss:1.1796
#
# EPOCH[49] - STEP[160]
# Generator_loss:2.3208
# L1_loss:0.1462
# Discriminator_loss:1.6670
#
# EPOCH[49] - STEP[180]
# Generator_loss:2.1134
# L1_loss:0.2191
# Discriminator_loss:0.2018
#
# EPOCH[49] - STEP[200]
# Generator_loss:1.3325
# L1_loss:0.1897
# Discriminator_loss:0.8290
#
# EPOCH[49] - STEP[220]
# Generator_loss:1.5012
# L1_loss:0.1518
# Discriminator_loss:0.8380
#
# EPOCH[49] - STEP[240]
# Generator_loss:1.8335
# L1_loss:0.1814
# Discriminator_loss:0.5611
#
# EPOCH[50] - STEP[20]
# Generator_loss:1.2907
# L1_loss:0.1662
# Discriminator_loss:0.5489
#
# EPOCH[50] - STEP[40]
# Generator_loss:1.5209
# L1_loss:0.1525
# Discriminator_loss:3.6095
#
# EPOCH[50] - STEP[60]
# Generator_loss:1.2239
# L1_loss:0.1403
# Discriminator_loss:1.5235
#
# EPOCH[50] - STEP[80]
# Generator_loss:1.2935
# L1_loss:0.1885
# Discriminator_loss:1.0046
#
# EPOCH[50] - STEP[100]
# Generator_loss:0.9648
# L1_loss:0.1591
# Discriminator_loss:0.7998
#
# EPOCH[50] - STEP[120]
# Generator_loss:0.4712
# L1_loss:0.1526
# Discriminator_loss:1.6054
#
# EPOCH[50] - STEP[140]
# Generator_loss:0.1554
# L1_loss:0.1668
# Discriminator_loss:2.8998
#
# EPOCH[50] - STEP[160]
# Generator_loss:1.8804
# L1_loss:0.1730
# Discriminator_loss:0.5973
#
# EPOCH[50] - STEP[180]
# Generator_loss:0.9555
# L1_loss:0.1554
# Discriminator_loss:0.7269
#
# EPOCH[50] - STEP[200]
# Generator_loss:0.6313
# L1_loss:0.1803
# Discriminator_loss:0.9245
#
# EPOCH[50] - STEP[220]
# Generator_loss:1.1266
# L1_loss:0.1659
# Discriminator_loss:0.7968
#
# EPOCH[50] - STEP[240]
# Generator_loss:1.0554
# L1_loss:0.1688
# Discriminator_loss:0.8688

# %%
test_ind = 0

f = val_path + os.listdir(val_path)[test_ind]
segment_map,road = load_img(f)

pred = generator(tf.expand_dims(segment_map, 0))
pred = denormalize(pred)

plt.figure(figsize=(20,10))
plt.subplot(1,3,1); plt.imshow(denormalize(segment_map))
plt.subplot(1,3,2); plt.imshow(pred[0])
plt.subplot(1,3,3); plt.imshow(denormalize(road))

# %% [markdown]
# #### epoch 50
# 결과를 보면 epoch 10번 했을떄의 결과보다 더 실제 도로의 모습과 흡사해 졌습니다.
# 이것으로 epoch를 증가함에따라 더 좋은 결과가 나오는것을 확인할 수 있게 되었네요.
#
# 반복횟수를 50 -> 120으로 증가해서 결과를 다시 확인 해보겠습니다.

# %% [markdown]
# #### epoch 120

# %%
EPOCHS = 120

generator = UNetGenerator()
discriminator = Discriminator()

for epoch in range(1, EPOCHS+1):
    for i, (segment_map, road) in enumerate(train_images):
        g_loss, l1_loss, d_loss = train_step(segment_map, road)

        # 20회 반복(iter)마다 손실을 출력합니다.
        if (i+1) % 40 == 0:  
            print(f"EPOCH[{epoch}] - STEP[{i+1}] \
                    \nGenerator_loss:{g_loss.numpy():.4f} \
                    \nL1_loss:{l1_loss.numpy():.4f} \
                    \nDiscriminator_loss:{d_loss.numpy():.4f}", end="\n\n")
# Out:
# EPOCH[1] - STEP[40]
# Generator_loss:0.7609
# L1_loss:0.2327
# Discriminator_loss:1.3827
#
# EPOCH[1] - STEP[80]
# Generator_loss:1.2548
# L1_loss:0.1661
# Discriminator_loss:1.1857
#
# EPOCH[1] - STEP[120]
# Generator_loss:1.1202
# L1_loss:0.2247
# Discriminator_loss:0.8726
#
# EPOCH[1] - STEP[160]
# Generator_loss:1.4678
# L1_loss:0.1812
# Discriminator_loss:1.4110
#
# EPOCH[1] - STEP[200]
# Generator_loss:1.5869
# L1_loss:0.2298
# Discriminator_loss:1.0314
#
# EPOCH[1] - STEP[240]
# Generator_loss:1.8609
# L1_loss:0.1738
# Discriminator_loss:1.3135
#
# EPOCH[2] - STEP[40]
# Generator_loss:2.4778
# L1_loss:0.1818
# Discriminator_loss:1.6418
#
# EPOCH[2] - STEP[80]
# Generator_loss:0.6811
# L1_loss:0.1748
# Discriminator_loss:0.9434
#
# EPOCH[2] - STEP[120]
# Generator_loss:1.7456
# L1_loss:0.1567
# Discriminator_loss:1.5853
#
# EPOCH[2] - STEP[160]
# Generator_loss:2.8094
# L1_loss:0.1963
# Discriminator_loss:0.5501
#
# EPOCH[2] - STEP[200]
# Generator_loss:1.2436
# L1_loss:0.2116
# Discriminator_loss:0.5105
#
# EPOCH[2] - STEP[240]
# Generator_loss:0.4577
# L1_loss:0.1798
# Discriminator_loss:1.3474
#
# EPOCH[3] - STEP[40]
# Generator_loss:0.6611
# L1_loss:0.1561
# Discriminator_loss:1.1575
#
# EPOCH[3] - STEP[80]
# Generator_loss:1.4514
# L1_loss:0.1979
# Discriminator_loss:0.6758
#
# EPOCH[3] - STEP[120]
# Generator_loss:1.8965
# L1_loss:0.1743
# Discriminator_loss:0.7571
#
# EPOCH[3] - STEP[160]
# Generator_loss:1.5410
# L1_loss:0.1452
# Discriminator_loss:1.2511
#
# EPOCH[3] - STEP[200]
# Generator_loss:1.1537
# L1_loss:0.1630
# Discriminator_loss:0.9189
#
# EPOCH[3] - STEP[240]
# Generator_loss:1.7008
# L1_loss:0.1681
# Discriminator_loss:0.9875
#
# EPOCH[4] - STEP[40]
# Generator_loss:1.0848
# L1_loss:0.1940
# Discriminator_loss:0.7163
#
# EPOCH[4] - STEP[80]
# Generator_loss:1.5502
# L1_loss:0.1856
# Discriminator_loss:0.6428
#
# EPOCH[4] - STEP[120]
# Generator_loss:1.2023
# L1_loss:0.1971
# Discriminator_loss:0.5165
#
# EPOCH[4] - STEP[160]
# Generator_loss:1.3681
# L1_loss:0.1821
# Discriminator_loss:0.5294
#
# EPOCH[4] - STEP[200]
# Generator_loss:1.6705
# L1_loss:0.1696
# Discriminator_loss:0.5008
#
# EPOCH[4] - STEP[240]
# Generator_loss:1.1983
# L1_loss:0.2071
# Discriminator_loss:0.5967
#
# EPOCH[5] - STEP[40]
# Generator_loss:2.0188
# L1_loss:0.1695
# Discriminator_loss:0.7300
#
# EPOCH[5] - STEP[80]
# Generator_loss:1.5891
# L1_loss:0.1812
# Discriminator_loss:0.4293
#
# EPOCH[5] - STEP[120]
# Generator_loss:1.6923
# L1_loss:0.1648
# Discriminator_loss:0.4543
#
# EPOCH[5] - STEP[160]
# Generator_loss:2.2845
# L1_loss:0.1754
# Discriminator_loss:0.7259
#
# EPOCH[5] - STEP[200]
# Generator_loss:0.9640
# L1_loss:0.1495
# Discriminator_loss:0.8966
#
# EPOCH[5] - STEP[240]
# Generator_loss:1.4081
# L1_loss:0.1937
# Discriminator_loss:0.4348
#
# EPOCH[6] - STEP[40]
# Generator_loss:2.1061
# L1_loss:0.1595
# Discriminator_loss:0.9902
#
# EPOCH[6] - STEP[80]
# Generator_loss:1.3585
# L1_loss:0.1597
# Discriminator_loss:1.5555
#
# EPOCH[6] - STEP[120]
# Generator_loss:2.0485
# L1_loss:0.1797
# Discriminator_loss:0.5136
#
# EPOCH[6] - STEP[160]
# Generator_loss:1.3757
# L1_loss:0.1666
# Discriminator_loss:1.1540
#
# EPOCH[6] - STEP[200]
# Generator_loss:2.2329
# L1_loss:0.1705
# Discriminator_loss:0.4457
#
# EPOCH[6] - STEP[240]
# Generator_loss:1.1630
# L1_loss:0.1590
# Discriminator_loss:0.8284
#
# EPOCH[7] - STEP[40]
# Generator_loss:2.6556
# L1_loss:0.1574
# Discriminator_loss:0.6123
#
# EPOCH[7] - STEP[80]
# Generator_loss:2.7315
# L1_loss:0.1938
# Discriminator_loss:0.6888
#
# EPOCH[7] - STEP[120]
# Generator_loss:1.3296
# L1_loss:0.1594
# Discriminator_loss:0.7035
#
# EPOCH[7] - STEP[160]
# Generator_loss:1.4029
# L1_loss:0.1547
# Discriminator_loss:0.7646
#
# EPOCH[7] - STEP[200]
# Generator_loss:1.7820
# L1_loss:0.1741
# Discriminator_loss:0.4075
#
# EPOCH[7] - STEP[240]
# Generator_loss:0.7168
# L1_loss:0.1938
# Discriminator_loss:0.8755
#
# EPOCH[8] - STEP[40]
# Generator_loss:1.1398
# L1_loss:0.1912
# Discriminator_loss:0.6019
#
# EPOCH[8] - STEP[80]
# Generator_loss:2.8395
# L1_loss:0.1605
# Discriminator_loss:0.3655
#
# EPOCH[8] - STEP[120]
# Generator_loss:0.9574
# L1_loss:0.1642
# Discriminator_loss:0.6591
#
# EPOCH[8] - STEP[160]
# Generator_loss:0.8328
# L1_loss:0.1613
# Discriminator_loss:1.1050
#
# EPOCH[8] - STEP[200]
# Generator_loss:1.2106
# L1_loss:0.1595
# Discriminator_loss:0.6557
#
# EPOCH[8] - STEP[240]
# Generator_loss:0.4915
# L1_loss:0.1514
# Discriminator_loss:1.3911
#
# EPOCH[9] - STEP[40]
# Generator_loss:1.6441
# L1_loss:0.2011
# Discriminator_loss:0.9334
#
# EPOCH[9] - STEP[80]
# Generator_loss:0.3000
# L1_loss:0.1541
# Discriminator_loss:1.7246
#
# EPOCH[9] - STEP[120]
# Generator_loss:1.0895
# L1_loss:0.1629
# Discriminator_loss:1.5688
#
# EPOCH[9] - STEP[160]
# Generator_loss:2.2808
# L1_loss:0.1659
# Discriminator_loss:1.1045
#
# EPOCH[9] - STEP[200]
# Generator_loss:1.9374
# L1_loss:0.1760
# Discriminator_loss:1.4204
#
# EPOCH[9] - STEP[240]
# Generator_loss:0.5600
# L1_loss:0.1656
# Discriminator_loss:1.6744
#
# EPOCH[10] - STEP[40]
# Generator_loss:2.4090
# L1_loss:0.1626
# Discriminator_loss:0.8917
#
# EPOCH[10] - STEP[80]
# Generator_loss:0.7587
# L1_loss:0.1816
# Discriminator_loss:0.7705
# EPOCH[10] - STEP[120]
# Generator_loss:0.8469
# L1_loss:0.1609
# Discriminator_loss:1.7491
#
# EPOCH[10] - STEP[160]
# Generator_loss:0.9330
# L1_loss:0.1762
# Discriminator_loss:0.9355
#
# EPOCH[10] - STEP[200]
# Generator_loss:1.6770
# L1_loss:0.1781
# Discriminator_loss:0.4174
#
# EPOCH[10] - STEP[240]
# Generator_loss:1.5804
# L1_loss:0.1862
# Discriminator_loss:0.4901
#
# EPOCH[11] - STEP[40]
# Generator_loss:2.3570
# L1_loss:0.1822
# Discriminator_loss:0.4157
#
# EPOCH[11] - STEP[80]
# Generator_loss:2.5984
# L1_loss:0.1593
# Discriminator_loss:0.8838
#
# EPOCH[11] - STEP[120]
# Generator_loss:2.4488
# L1_loss:0.2045
# Discriminator_loss:0.2553
#
# EPOCH[11] - STEP[160]
# Generator_loss:1.2607
# L1_loss:0.1751
# Discriminator_loss:1.8450
#
# EPOCH[11] - STEP[200]
# Generator_loss:0.1382
# L1_loss:0.1372
# Discriminator_loss:2.5172
#
# EPOCH[11] - STEP[240]
# Generator_loss:1.6095
# L1_loss:0.1873
# Discriminator_loss:0.3562
#
# EPOCH[12] - STEP[40]
# Generator_loss:2.2850
# L1_loss:0.1990
# Discriminator_loss:0.2140
#
# EPOCH[12] - STEP[80]
# Generator_loss:0.6253
# L1_loss:0.1758
# Discriminator_loss:0.9590
#
# EPOCH[12] - STEP[120]
# Generator_loss:1.6622
# L1_loss:0.1660
# Discriminator_loss:0.6353
#
# EPOCH[12] - STEP[160]
# Generator_loss:1.7512
# L1_loss:0.1606
# Discriminator_loss:0.5203
#
# EPOCH[12] - STEP[200]
# Generator_loss:1.0090
# L1_loss:0.1547
# Discriminator_loss:1.3605
#
# EPOCH[12] - STEP[240]
# Generator_loss:0.8217
# L1_loss:0.1719
# Discriminator_loss:1.1818
#
# EPOCH[13] - STEP[40]
# Generator_loss:1.8605
# L1_loss:0.1628
# Discriminator_loss:0.6208
#
# EPOCH[13] - STEP[80]
# Generator_loss:0.9757
# L1_loss:0.1571
# Discriminator_loss:1.0621
#
# EPOCH[13] - STEP[120]
# Generator_loss:1.8406
# L1_loss:0.1709
# Discriminator_loss:0.8145
#
# EPOCH[13] - STEP[160]
# Generator_loss:2.4018
# L1_loss:0.1651
# Discriminator_loss:0.9637
#
# EPOCH[13] - STEP[200]
# Generator_loss:1.3970
# L1_loss:0.1585
# Discriminator_loss:0.4857
#
# EPOCH[13] - STEP[240]
# Generator_loss:1.2793
# L1_loss:0.1454
# Discriminator_loss:1.2553
#
# EPOCH[14] - STEP[40]
# Generator_loss:1.9637
# L1_loss:0.1370
# Discriminator_loss:1.0445
#
# EPOCH[14] - STEP[80]
# Generator_loss:2.1428
# L1_loss:0.1482
# Discriminator_loss:0.8940
#
# EPOCH[14] - STEP[120]
# Generator_loss:0.8019
# L1_loss:0.1665
# Discriminator_loss:0.7951
#
# EPOCH[14] - STEP[160]
# Generator_loss:1.4763
# L1_loss:0.1700
# Discriminator_loss:0.7342
#
# EPOCH[14] - STEP[200]
# Generator_loss:1.2173
# L1_loss:0.1789
# Discriminator_loss:0.4390
#
# EPOCH[14] - STEP[240]
# Generator_loss:1.2953
# L1_loss:0.1728
# Discriminator_loss:0.5190
#
# EPOCH[15] - STEP[40]
# Generator_loss:0.4311
# L1_loss:0.1793
# Discriminator_loss:1.2358
#
# EPOCH[15] - STEP[80]
# Generator_loss:1.9550
# L1_loss:0.2040
# Discriminator_loss:0.2974
#
# EPOCH[15] - STEP[120]
# Generator_loss:1.6153
# L1_loss:0.1582
# Discriminator_loss:1.6487
#
# EPOCH[15] - STEP[160]
# Generator_loss:2.3320
# L1_loss:0.1722
# Discriminator_loss:1.5142
#
# EPOCH[15] - STEP[200]
# Generator_loss:0.9984
# L1_loss:0.1548
# Discriminator_loss:0.6597
#
# EPOCH[15] - STEP[240]
# Generator_loss:1.2539
# L1_loss:0.1899
# Discriminator_loss:0.6506
#
# EPOCH[16] - STEP[40]
# Generator_loss:1.6517
# L1_loss:0.1624
# Discriminator_loss:0.5343
#
# EPOCH[16] - STEP[80]
# Generator_loss:0.7812
# L1_loss:0.1703
# Discriminator_loss:0.7527
#
# EPOCH[16] - STEP[120]
# Generator_loss:1.7311
# L1_loss:0.1427
# Discriminator_loss:0.7460
#
# EPOCH[16] - STEP[160]
# Generator_loss:2.6738
# L1_loss:0.1779
# Discriminator_loss:0.5946
#
# EPOCH[16] - STEP[200]
# Generator_loss:0.7947
# L1_loss:0.1756
# Discriminator_loss:0.9411
#
# EPOCH[16] - STEP[240]
# Generator_loss:0.9737
# L1_loss:0.1912
# Discriminator_loss:0.5978
#
# EPOCH[17] - STEP[40]
# Generator_loss:0.6370
# L1_loss:0.1643
# Discriminator_loss:1.1855
#
# EPOCH[17] - STEP[80]
# Generator_loss:1.7295
# L1_loss:0.1733
# Discriminator_loss:1.0698
#
# EPOCH[17] - STEP[120]
# Generator_loss:1.0667
# L1_loss:0.1490
# Discriminator_loss:1.4300
#
# EPOCH[17] - STEP[160]
# Generator_loss:2.6361
# L1_loss:0.1690
# Discriminator_loss:0.6127
#
# EPOCH[17] - STEP[200]
# Generator_loss:0.9948
# L1_loss:0.1525
# Discriminator_loss:1.3787
#
# EPOCH[17] - STEP[240]
# Generator_loss:1.7805
# L1_loss:0.1460
# Discriminator_loss:0.8714
#
# EPOCH[18] - STEP[40]
# Generator_loss:0.8494
# L1_loss:0.1501
# Discriminator_loss:1.5181
#
# EPOCH[18] - STEP[80]
# Generator_loss:1.5750
# L1_loss:0.1645
# Discriminator_loss:0.5708
#
# EPOCH[18] - STEP[120]
# Generator_loss:2.3461
# L1_loss:0.1589
# Discriminator_loss:0.8455
#
# EPOCH[18] - STEP[160]
# Generator_loss:3.1512
# L1_loss:0.1544
# Discriminator_loss:1.9642
#
# EPOCH[18] - STEP[200]
# Generator_loss:1.5265
# L1_loss:0.1929
# Discriminator_loss:0.7421
#
# EPOCH[18] - STEP[240]
# Generator_loss:1.5233
# L1_loss:0.1572
# Discriminator_loss:1.0175
#
# EPOCH[19] - STEP[40]
# Generator_loss:2.0122
# L1_loss:0.2116
# Discriminator_loss:0.1965
#
# EPOCH[19] - STEP[80]
# Generator_loss:1.9124
# L1_loss:0.1933
# Discriminator_loss:0.2881
#
# EPOCH[19] - STEP[120]
# Generator_loss:1.0366
# L1_loss:0.1721
# Discriminator_loss:0.5865
#
# EPOCH[19] - STEP[160]
# Generator_loss:1.9199
# L1_loss:0.1858
# Discriminator_loss:0.3398
# EPOCH[19] - STEP[200]
# Generator_loss:2.6430
# L1_loss:0.1974
# Discriminator_loss:0.3452
#
# EPOCH[19] - STEP[240]
# Generator_loss:0.3205
# L1_loss:0.1680
# Discriminator_loss:1.4868
#
# EPOCH[20] - STEP[40]
# Generator_loss:1.0682
# L1_loss:0.1876
# Discriminator_loss:0.6381
#
# EPOCH[20] - STEP[80]
# Generator_loss:0.9429
# L1_loss:0.1493
# Discriminator_loss:0.6879
#
# EPOCH[20] - STEP[120]
# Generator_loss:0.5371
# L1_loss:0.2110
# Discriminator_loss:1.1143
#
# EPOCH[20] - STEP[160]
# Generator_loss:1.1054
# L1_loss:0.1666
# Discriminator_loss:0.8351
#
# EPOCH[20] - STEP[200]
# Generator_loss:0.9306
# L1_loss:0.1417
# Discriminator_loss:0.8620
#
# EPOCH[20] - STEP[240]
# Generator_loss:1.4222
# L1_loss:0.1339
# Discriminator_loss:1.1080
#
# EPOCH[21] - STEP[40]
# Generator_loss:1.2341
# L1_loss:0.1726
# Discriminator_loss:0.5315
#
# EPOCH[21] - STEP[80]
# Generator_loss:0.5597
# L1_loss:0.1565
# Discriminator_loss:1.2164
#
# EPOCH[21] - STEP[120]
# Generator_loss:1.3181
# L1_loss:0.1760
# Discriminator_loss:0.8552
#
# EPOCH[21] - STEP[160]
# Generator_loss:1.0219
# L1_loss:0.2063
# Discriminator_loss:0.6841
#
# EPOCH[21] - STEP[200]
# Generator_loss:1.5267
# L1_loss:0.1653
# Discriminator_loss:0.4494
#
# EPOCH[21] - STEP[240]
# Generator_loss:1.5108
# L1_loss:0.1719
# Discriminator_loss:0.5811
#
# EPOCH[22] - STEP[40]
# Generator_loss:0.7445
# L1_loss:0.1381
# Discriminator_loss:1.8078
#
# EPOCH[22] - STEP[80]
# Generator_loss:1.5923
# L1_loss:0.1729
# Discriminator_loss:0.6337
#
# EPOCH[22] - STEP[120]
# Generator_loss:0.9887
# L1_loss:0.1894
# Discriminator_loss:0.7652
#
# EPOCH[22] - STEP[160]
# Generator_loss:1.1214
# L1_loss:0.1616
# Discriminator_loss:0.5137
#
# EPOCH[22] - STEP[200]
# Generator_loss:2.1559
# L1_loss:0.1595
# Discriminator_loss:1.1070
#
# EPOCH[22] - STEP[240]
# Generator_loss:0.3152
# L1_loss:0.1466
# Discriminator_loss:1.5954
#
# EPOCH[23] - STEP[40]
# Generator_loss:1.8904
# L1_loss:0.1386
# Discriminator_loss:1.4988
#
# EPOCH[23] - STEP[80]
# Generator_loss:1.6221
# L1_loss:0.1811
# Discriminator_loss:0.7036
#
# EPOCH[23] - STEP[120]
# Generator_loss:0.2377
# L1_loss:0.1555
# Discriminator_loss:2.2407
#
# EPOCH[23] - STEP[160]
# Generator_loss:1.2996
# L1_loss:0.1837
# Discriminator_loss:0.5508
#
# EPOCH[23] - STEP[200]
# Generator_loss:2.1079
# L1_loss:0.1602
# Discriminator_loss:1.0202
#
# EPOCH[23] - STEP[240]
# Generator_loss:1.2861
# L1_loss:0.1343
# Discriminator_loss:1.2800
#
# EPOCH[24] - STEP[40]
# Generator_loss:0.6492
# L1_loss:0.1750
# Discriminator_loss:0.9284
#
# EPOCH[24] - STEP[80]
# Generator_loss:1.3719
# L1_loss:0.1444
# Discriminator_loss:1.2901
#
# EPOCH[24] - STEP[120]
# Generator_loss:1.3953
# L1_loss:0.2270
# Discriminator_loss:0.3536
#
# EPOCH[24] - STEP[160]
# Generator_loss:0.8400
# L1_loss:0.1620
# Discriminator_loss:0.6918
#
# EPOCH[24] - STEP[200]
# Generator_loss:1.6231
# L1_loss:0.1452
# Discriminator_loss:0.6655
#
# EPOCH[24] - STEP[240]
# Generator_loss:1.0370
# L1_loss:0.1585
# Discriminator_loss:0.8914
#
# EPOCH[25] - STEP[40]
# Generator_loss:1.8064
# L1_loss:0.1745
# Discriminator_loss:0.3587
#
# EPOCH[25] - STEP[80]
# Generator_loss:2.2800
# L1_loss:0.1624
# Discriminator_loss:0.3971
#
# EPOCH[25] - STEP[120]
# Generator_loss:2.3748
# L1_loss:0.2023
# Discriminator_loss:0.4577
#
# EPOCH[25] - STEP[160]
# Generator_loss:1.6734
# L1_loss:0.1560
# Discriminator_loss:0.7344
#
# EPOCH[25] - STEP[200]
# Generator_loss:0.6129
# L1_loss:0.1508
# Discriminator_loss:1.0142
#
# EPOCH[25] - STEP[240]
# Generator_loss:1.3048
# L1_loss:0.1938
# Discriminator_loss:0.4254
#
# EPOCH[26] - STEP[40]
# Generator_loss:0.3455
# L1_loss:0.1866
# Discriminator_loss:1.4221
#
# EPOCH[26] - STEP[80]
# Generator_loss:1.7730
# L1_loss:0.1499
# Discriminator_loss:1.4722
#
# EPOCH[26] - STEP[120]
# Generator_loss:1.3127
# L1_loss:0.1852
# Discriminator_loss:0.4969
#
# EPOCH[26] - STEP[160]
# Generator_loss:0.9785
# L1_loss:0.1555
# Discriminator_loss:0.8480
#
# EPOCH[26] - STEP[200]
# Generator_loss:1.2826
# L1_loss:0.1758
# Discriminator_loss:0.5177
#
# EPOCH[26] - STEP[240]
# Generator_loss:1.2170
# L1_loss:0.1368
# Discriminator_loss:1.7490
#
# EPOCH[27] - STEP[40]
# Generator_loss:0.5740
# L1_loss:0.1880
# Discriminator_loss:0.9579
#
# EPOCH[27] - STEP[80]
# Generator_loss:1.5643
# L1_loss:0.2154
# Discriminator_loss:0.3126
#
# EPOCH[27] - STEP[120]
# Generator_loss:2.3421
# L1_loss:0.1620
# Discriminator_loss:1.6523
#
# EPOCH[27] - STEP[160]
# Generator_loss:0.9905
# L1_loss:0.1577
# Discriminator_loss:1.0436
#
# EPOCH[27] - STEP[200]
# Generator_loss:0.9251
# L1_loss:0.1586
# Discriminator_loss:0.8559
#
# EPOCH[27] - STEP[240]
# Generator_loss:1.2615
# L1_loss:0.1695
# Discriminator_loss:0.6300
#
# EPOCH[28] - STEP[40]
# Generator_loss:0.3837
# L1_loss:0.1647
# Discriminator_loss:1.4472
#
# EPOCH[28] - STEP[80]
# Generator_loss:0.9262
# L1_loss:0.1555
# Discriminator_loss:1.3556
#
# EPOCH[28] - STEP[120]
# Generator_loss:0.8031
# L1_loss:0.1683
# Discriminator_loss:2.1300
#
# EPOCH[28] - STEP[160]
# Generator_loss:1.5998
# L1_loss:0.1626
# Discriminator_loss:0.5605
#
# EPOCH[28] - STEP[200]
# Generator_loss:1.5679
# L1_loss:0.1326
# Discriminator_loss:1.2694
#
# EPOCH[28] - STEP[240]
# Generator_loss:0.6091
# L1_loss:0.1597
# Discriminator_loss:1.0877
# EPOCH[29] - STEP[40]
# Generator_loss:1.0939
# L1_loss:0.1635
# Discriminator_loss:0.7757
#
# EPOCH[29] - STEP[80]
# Generator_loss:0.9752
# L1_loss:0.1595
# Discriminator_loss:1.0512
#
# EPOCH[29] - STEP[120]
# Generator_loss:1.7199
# L1_loss:0.1609
# Discriminator_loss:0.8561
#
# EPOCH[29] - STEP[160]
# Generator_loss:1.2871
# L1_loss:0.2102
# Discriminator_loss:0.4093
#
# EPOCH[29] - STEP[200]
# Generator_loss:0.7709
# L1_loss:0.1399
# Discriminator_loss:1.5076
#
# EPOCH[29] - STEP[240]
# Generator_loss:1.7266
# L1_loss:0.1448
# Discriminator_loss:1.7414
#
# EPOCH[30] - STEP[40]
# Generator_loss:0.3791
# L1_loss:0.1737
# Discriminator_loss:1.4859
#
# EPOCH[30] - STEP[80]
# Generator_loss:0.9768
# L1_loss:0.1655
# Discriminator_loss:1.7813
#
# EPOCH[30] - STEP[120]
# Generator_loss:1.8178
# L1_loss:0.1664
# Discriminator_loss:0.3307
#
# EPOCH[30] - STEP[160]
# Generator_loss:0.5781
# L1_loss:0.1856
# Discriminator_loss:1.0408
#
# EPOCH[30] - STEP[200]
# Generator_loss:1.2462
# L1_loss:0.1606
# Discriminator_loss:0.9091
#
# EPOCH[30] - STEP[240]
# Generator_loss:0.9449
# L1_loss:0.1552
# Discriminator_loss:0.8613
#
# EPOCH[31] - STEP[40]
# Generator_loss:1.3433
# L1_loss:0.1758
# Discriminator_loss:0.3929
#
# EPOCH[31] - STEP[80]
# Generator_loss:0.9266
# L1_loss:0.1707
# Discriminator_loss:0.6112
#
# EPOCH[31] - STEP[120]
# Generator_loss:0.6413
# L1_loss:0.1578
# Discriminator_loss:1.9734
#
# EPOCH[31] - STEP[160]
# Generator_loss:0.5159
# L1_loss:0.1933
# Discriminator_loss:1.0448
#
# EPOCH[31] - STEP[200]
# Generator_loss:1.4543
# L1_loss:0.1651
# Discriminator_loss:1.2849
#
# EPOCH[31] - STEP[240]
# Generator_loss:1.1436
# L1_loss:0.1695
# Discriminator_loss:0.6748
#
# EPOCH[32] - STEP[40]
# Generator_loss:0.8931
# L1_loss:0.1614
# Discriminator_loss:0.8304
#
# EPOCH[32] - STEP[80]
# Generator_loss:1.0544
# L1_loss:0.2124
# Discriminator_loss:0.5778
#
# EPOCH[32] - STEP[120]
# Generator_loss:0.8046
# L1_loss:0.1704
# Discriminator_loss:0.8154
#
# EPOCH[32] - STEP[160]
# Generator_loss:1.1601
# L1_loss:0.1387
# Discriminator_loss:1.0484
#
# EPOCH[32] - STEP[200]
# Generator_loss:1.0452
# L1_loss:0.1841
# Discriminator_loss:0.5244
#
# EPOCH[32] - STEP[240]
# Generator_loss:1.7650
# L1_loss:0.1545
# Discriminator_loss:0.8110
#
# EPOCH[33] - STEP[40]
# Generator_loss:1.6059
# L1_loss:0.1432
# Discriminator_loss:0.5008
#
# EPOCH[33] - STEP[80]
# Generator_loss:1.8423
# L1_loss:0.1775
# Discriminator_loss:0.6683
#
# EPOCH[33] - STEP[120]
# Generator_loss:0.6675
# L1_loss:0.1807
# Discriminator_loss:0.8553
#
# EPOCH[33] - STEP[160]
# Generator_loss:1.9944
# L1_loss:0.1771
# Discriminator_loss:0.6376
#
# EPOCH[33] - STEP[200]
# Generator_loss:0.9533
# L1_loss:0.1518
# Discriminator_loss:0.9653
#
# EPOCH[33] - STEP[240]
# Generator_loss:1.2580
# L1_loss:0.1912
# Discriminator_loss:0.4682
#
# EPOCH[34] - STEP[40]
# Generator_loss:0.9525
# L1_loss:0.1847
# Discriminator_loss:0.6365
#
# EPOCH[34] - STEP[80]
# Generator_loss:2.7286
# L1_loss:0.1743
# Discriminator_loss:0.3627
#
# EPOCH[34] - STEP[120]
# Generator_loss:1.5667
# L1_loss:0.1784
# Discriminator_loss:0.7526
#
# EPOCH[34] - STEP[160]
# Generator_loss:2.9843
# L1_loss:0.1344
# Discriminator_loss:2.5311
#
# EPOCH[34] - STEP[200]
# Generator_loss:2.0518
# L1_loss:0.1726
# Discriminator_loss:0.6574
#
# EPOCH[34] - STEP[240]
# Generator_loss:0.5687
# L1_loss:0.1711
# Discriminator_loss:1.3226
#
# EPOCH[35] - STEP[40]
# Generator_loss:0.4251
# L1_loss:0.1680
# Discriminator_loss:1.9019
#
# EPOCH[35] - STEP[80]
# Generator_loss:1.4497
# L1_loss:0.1566
# Discriminator_loss:1.1891
#
# EPOCH[35] - STEP[120]
# Generator_loss:2.9511
# L1_loss:0.1916
# Discriminator_loss:0.1658
#
# EPOCH[35] - STEP[160]
# Generator_loss:1.6979
# L1_loss:0.1808
# Discriminator_loss:0.5265
#
# EPOCH[35] - STEP[200]
# Generator_loss:2.0909
# L1_loss:0.1647
# Discriminator_loss:0.5645
#
# EPOCH[35] - STEP[240]
# Generator_loss:1.7657
# L1_loss:0.1905
# Discriminator_loss:0.2721
#
# EPOCH[36] - STEP[40]
# Generator_loss:1.4871
# L1_loss:0.1601
# Discriminator_loss:0.6655
#
# EPOCH[36] - STEP[80]
# Generator_loss:1.6086
# L1_loss:0.1872
# Discriminator_loss:0.8921
#
# EPOCH[36] - STEP[120]
# Generator_loss:1.2553
# L1_loss:0.1609
# Discriminator_loss:0.6422
#
# EPOCH[36] - STEP[160]
# Generator_loss:1.5455
# L1_loss:0.1405
# Discriminator_loss:1.5897
#
# EPOCH[36] - STEP[200]
# Generator_loss:1.1369
# L1_loss:0.2039
# Discriminator_loss:0.4741
#
# EPOCH[36] - STEP[240]
# Generator_loss:1.8616
# L1_loss:0.1758
# Discriminator_loss:0.6697
#
# EPOCH[37] - STEP[40]
# Generator_loss:1.4629
# L1_loss:0.1628
# Discriminator_loss:1.3544
#
# EPOCH[37] - STEP[80]
# Generator_loss:1.2815
# L1_loss:0.1752
# Discriminator_loss:1.1662
#
# EPOCH[37] - STEP[120]
# Generator_loss:1.8184
# L1_loss:0.1519
# Discriminator_loss:2.0912
#
# EPOCH[37] - STEP[160]
# Generator_loss:1.5497
# L1_loss:0.1556
# Discriminator_loss:1.3267
#
# EPOCH[37] - STEP[200]
# Generator_loss:0.9139
# L1_loss:0.1531
# Discriminator_loss:1.3535
#
# EPOCH[37] - STEP[240]
# Generator_loss:0.6003
# L1_loss:0.1640
# Discriminator_loss:1.2676
#
# EPOCH[38] - STEP[40]
# Generator_loss:2.4379
# L1_loss:0.1551
# Discriminator_loss:0.5232
#
# EPOCH[38] - STEP[80]
# Generator_loss:0.2452
# L1_loss:0.1479
# Discriminator_loss:1.8192
# EPOCH[38] - STEP[120]
# Generator_loss:0.9560
# L1_loss:0.1630
# Discriminator_loss:0.7597
#
# EPOCH[38] - STEP[160]
# Generator_loss:2.3143
# L1_loss:0.1769
# Discriminator_loss:0.9911
#
# EPOCH[38] - STEP[200]
# Generator_loss:1.0160
# L1_loss:0.1581
# Discriminator_loss:1.1594
#
# EPOCH[38] - STEP[240]
# Generator_loss:2.3879
# L1_loss:0.1422
# Discriminator_loss:1.5130
#
# EPOCH[39] - STEP[40]
# Generator_loss:1.8335
# L1_loss:0.1618
# Discriminator_loss:0.6972
#
# EPOCH[39] - STEP[80]
# Generator_loss:1.8009
# L1_loss:0.1714
# Discriminator_loss:1.0743
#
# EPOCH[39] - STEP[120]
# Generator_loss:1.1437
# L1_loss:0.1545
# Discriminator_loss:0.8392
#
# EPOCH[39] - STEP[160]
# Generator_loss:0.5800
# L1_loss:0.1623
# Discriminator_loss:1.4621
#
# EPOCH[39] - STEP[200]
# Generator_loss:1.3676
# L1_loss:0.1931
# Discriminator_loss:0.5832
#
# EPOCH[39] - STEP[240]
# Generator_loss:1.2798
# L1_loss:0.1629
# Discriminator_loss:0.5833
#
# EPOCH[40] - STEP[40]
# Generator_loss:1.9130
# L1_loss:0.1581
# Discriminator_loss:0.5047
#
# EPOCH[40] - STEP[80]
# Generator_loss:2.6934
# L1_loss:0.1381
# Discriminator_loss:1.0533
#
# EPOCH[40] - STEP[120]
# Generator_loss:0.8187
# L1_loss:0.1641
# Discriminator_loss:0.9998
#
# EPOCH[40] - STEP[160]
# Generator_loss:1.1823
# L1_loss:0.1557
# Discriminator_loss:2.5160
#
# EPOCH[40] - STEP[200]
# Generator_loss:2.3373
# L1_loss:0.1378
# Discriminator_loss:2.5949
#
# EPOCH[40] - STEP[240]
# Generator_loss:0.9588
# L1_loss:0.1961
# Discriminator_loss:0.5574
#
# EPOCH[41] - STEP[40]
# Generator_loss:2.4332
# L1_loss:0.1411
# Discriminator_loss:1.9468
#
# EPOCH[41] - STEP[80]
# Generator_loss:1.8439
# L1_loss:0.1983
# Discriminator_loss:0.2873
#
# EPOCH[41] - STEP[120]
# Generator_loss:0.6771
# L1_loss:0.1439
# Discriminator_loss:1.0507
#
# EPOCH[41] - STEP[160]
# Generator_loss:0.4664
# L1_loss:0.1824
# Discriminator_loss:1.2181
#
# EPOCH[41] - STEP[200]
# Generator_loss:1.1692
# L1_loss:0.1663
# Discriminator_loss:0.5899
#
# EPOCH[41] - STEP[240]
# Generator_loss:0.6694
# L1_loss:0.1451
# Discriminator_loss:0.9769
#
# EPOCH[42] - STEP[40]
# Generator_loss:1.9019
# L1_loss:0.1636
# Discriminator_loss:0.4217
#
# EPOCH[42] - STEP[80]
# Generator_loss:1.7689
# L1_loss:0.1546
# Discriminator_loss:0.9754
#
# EPOCH[42] - STEP[120]
# Generator_loss:1.8904
# L1_loss:0.1587
# Discriminator_loss:0.8837
#
# EPOCH[42] - STEP[160]
# Generator_loss:1.1141
# L1_loss:0.1497
# Discriminator_loss:0.7157
#
# EPOCH[42] - STEP[200]
# Generator_loss:1.6935
# L1_loss:0.1778
# Discriminator_loss:1.0786
#
# EPOCH[42] - STEP[240]
# Generator_loss:1.6178
# L1_loss:0.1378
# Discriminator_loss:1.5002
#
# EPOCH[43] - STEP[40]
# Generator_loss:1.5661
# L1_loss:0.1773
# Discriminator_loss:0.4767
#
# EPOCH[43] - STEP[80]
# Generator_loss:1.3787
# L1_loss:0.1702
# Discriminator_loss:0.5669
#
# EPOCH[43] - STEP[120]
# Generator_loss:1.5428
# L1_loss:0.1560
# Discriminator_loss:0.9523
#
# EPOCH[43] - STEP[160]
# Generator_loss:1.6217
# L1_loss:0.1873
# Discriminator_loss:0.3783
#
# EPOCH[43] - STEP[200]
# Generator_loss:0.9535
# L1_loss:0.1619
# Discriminator_loss:0.6936
#
# EPOCH[43] - STEP[240]
# Generator_loss:1.2533
# L1_loss:0.1619
# Discriminator_loss:0.7764
#
# EPOCH[44] - STEP[40]
# Generator_loss:1.8965
# L1_loss:0.1266
# Discriminator_loss:1.6480
#
# EPOCH[44] - STEP[80]
# Generator_loss:1.7190
# L1_loss:0.1591
# Discriminator_loss:0.4325
#
# EPOCH[44] - STEP[120]
# Generator_loss:1.4093
# L1_loss:0.1658
# Discriminator_loss:1.1186
#
# EPOCH[44] - STEP[160]
# Generator_loss:1.1820
# L1_loss:0.1766
# Discriminator_loss:0.5930
#
# EPOCH[44] - STEP[200]
# Generator_loss:2.5439
# L1_loss:0.1709
# Discriminator_loss:1.6294
#
# EPOCH[44] - STEP[240]
# Generator_loss:1.3700
# L1_loss:0.1316
# Discriminator_loss:1.5272
#
# EPOCH[45] - STEP[40]
# Generator_loss:0.9881
# L1_loss:0.1575
# Discriminator_loss:0.9582
#
# EPOCH[45] - STEP[80]
# Generator_loss:1.8775
# L1_loss:0.1651
# Discriminator_loss:1.4021
#
# EPOCH[45] - STEP[120]
# Generator_loss:0.9247
# L1_loss:0.1667
# Discriminator_loss:0.9271
#
# EPOCH[45] - STEP[160]
# Generator_loss:1.2703
# L1_loss:0.1636
# Discriminator_loss:0.8523
#
# EPOCH[45] - STEP[200]
# Generator_loss:2.4354
# L1_loss:0.1583
# Discriminator_loss:1.1181
#
# EPOCH[45] - STEP[240]
# Generator_loss:2.1042
# L1_loss:0.1595
# Discriminator_loss:0.3567
#
# EPOCH[46] - STEP[40]
# Generator_loss:1.2041
# L1_loss:0.1667
# Discriminator_loss:0.6315
#
# EPOCH[46] - STEP[80]
# Generator_loss:2.7224
# L1_loss:0.1414
# Discriminator_loss:2.2757
#
# EPOCH[46] - STEP[120]
# Generator_loss:1.8970
# L1_loss:0.1654
# Discriminator_loss:0.8108
#
# EPOCH[46] - STEP[160]
# Generator_loss:1.9932
# L1_loss:0.2075
# Discriminator_loss:0.2839
#
# EPOCH[46] - STEP[200]
# Generator_loss:0.8870
# L1_loss:0.1864
# Discriminator_loss:0.6289
#
# EPOCH[46] - STEP[240]
# Generator_loss:0.8480
# L1_loss:0.1751
# Discriminator_loss:0.6843
#
# EPOCH[47] - STEP[40]
# Generator_loss:1.1171
# L1_loss:0.1775
# Discriminator_loss:0.7346
#
# EPOCH[47] - STEP[80]
# Generator_loss:1.2585
# L1_loss:0.1488
# Discriminator_loss:1.8833
#
# EPOCH[47] - STEP[120]
# Generator_loss:1.0053
# L1_loss:0.1509
# Discriminator_loss:1.2603
#
# EPOCH[47] - STEP[160]
# Generator_loss:1.1110
# L1_loss:0.1470
# Discriminator_loss:2.0570
# EPOCH[47] - STEP[200]
# Generator_loss:0.9696
# L1_loss:0.1877
# Discriminator_loss:0.8050
#
# EPOCH[47] - STEP[240]
# Generator_loss:1.6068
# L1_loss:0.1720
# Discriminator_loss:0.6809
#
# EPOCH[48] - STEP[40]
# Generator_loss:2.7107
# L1_loss:0.1470
# Discriminator_loss:1.5545
#
# EPOCH[48] - STEP[80]
# Generator_loss:1.3433
# L1_loss:0.2005
# Discriminator_loss:0.4000
#
# EPOCH[48] - STEP[120]
# Generator_loss:1.8834
# L1_loss:0.1625
# Discriminator_loss:0.4626
#
# EPOCH[48] - STEP[160]
# Generator_loss:2.3058
# L1_loss:0.1701
# Discriminator_loss:0.6015
#
# EPOCH[48] - STEP[200]
# Generator_loss:2.3930
# L1_loss:0.1892
# Discriminator_loss:0.5620
#
# EPOCH[48] - STEP[240]
# Generator_loss:1.7212
# L1_loss:0.1756
# Discriminator_loss:0.6833
#
# EPOCH[49] - STEP[40]
# Generator_loss:2.3005
# L1_loss:0.1484
# Discriminator_loss:2.3649
#
# EPOCH[49] - STEP[80]
# Generator_loss:0.6018
# L1_loss:0.1537
# Discriminator_loss:1.0163
#
# EPOCH[49] - STEP[120]
# Generator_loss:2.3383
# L1_loss:0.1827
# Discriminator_loss:0.2120
#
# EPOCH[49] - STEP[160]
# Generator_loss:1.4268
# L1_loss:0.1630
# Discriminator_loss:0.3693
#
# EPOCH[49] - STEP[200]
# Generator_loss:0.8303
# L1_loss:0.1797
# Discriminator_loss:0.7328
#
# EPOCH[49] - STEP[240]
# Generator_loss:1.1826
# L1_loss:0.1634
# Discriminator_loss:0.6014
#
# EPOCH[50] - STEP[40]
# Generator_loss:1.8769
# L1_loss:0.1829
# Discriminator_loss:0.2537
#
# EPOCH[50] - STEP[80]
# Generator_loss:1.5948
# L1_loss:0.1511
# Discriminator_loss:0.4641
#
# EPOCH[50] - STEP[120]
# Generator_loss:2.2954
# L1_loss:0.1941
# Discriminator_loss:0.2379
#
# EPOCH[50] - STEP[160]
# Generator_loss:0.9971
# L1_loss:0.1563
# Discriminator_loss:0.7176
#
# EPOCH[50] - STEP[200]
# Generator_loss:1.4904
# L1_loss:0.1523
# Discriminator_loss:0.5857
#
# EPOCH[50] - STEP[240]
# Generator_loss:1.8710
# L1_loss:0.1755
# Discriminator_loss:0.4118
#
# EPOCH[51] - STEP[40]
# Generator_loss:0.6923
# L1_loss:0.1808
# Discriminator_loss:0.9666
#
# EPOCH[51] - STEP[80]
# Generator_loss:1.0599
# L1_loss:0.2015
# Discriminator_loss:0.6872
#
# EPOCH[51] - STEP[120]
# Generator_loss:2.6066
# L1_loss:0.1588
# Discriminator_loss:1.0663
#
# EPOCH[51] - STEP[160]
# Generator_loss:2.4261
# L1_loss:0.1498
# Discriminator_loss:0.5255
#
# EPOCH[51] - STEP[200]
# Generator_loss:3.2915
# L1_loss:0.1669
# Discriminator_loss:1.2895
#
# EPOCH[51] - STEP[240]
# Generator_loss:1.4822
# L1_loss:0.1644
# Discriminator_loss:2.0935
#
# EPOCH[52] - STEP[40]
# Generator_loss:0.5312
# L1_loss:0.1576
# Discriminator_loss:1.1544
#
# EPOCH[52] - STEP[80]
# Generator_loss:0.5501
# L1_loss:0.1622
# Discriminator_loss:2.0519
#
# EPOCH[52] - STEP[120]
# Generator_loss:2.6156
# L1_loss:0.1648
# Discriminator_loss:1.4318
#
# EPOCH[52] - STEP[160]
# Generator_loss:2.4559
# L1_loss:0.1690
# Discriminator_loss:0.6239
#
# EPOCH[52] - STEP[200]
# Generator_loss:1.6360
# L1_loss:0.1348
# Discriminator_loss:1.3347
#
# EPOCH[52] - STEP[240]
# Generator_loss:1.8035
# L1_loss:0.1720
# Discriminator_loss:0.4750
#
# EPOCH[53] - STEP[40]
# Generator_loss:0.8916
# L1_loss:0.1373
# Discriminator_loss:1.4640
#
# EPOCH[53] - STEP[80]
# Generator_loss:1.7892
# L1_loss:0.1408
# Discriminator_loss:1.6759
#
# EPOCH[53] - STEP[120]
# Generator_loss:1.2620
# L1_loss:0.1456
# Discriminator_loss:0.9047
#
# EPOCH[53] - STEP[160]
# Generator_loss:0.9900
# L1_loss:0.2046
# Discriminator_loss:0.5506
#
# EPOCH[53] - STEP[200]
# Generator_loss:2.0736
# L1_loss:0.1510
# Discriminator_loss:0.4489
#
# EPOCH[53] - STEP[240]
# Generator_loss:0.7861
# L1_loss:0.1603
# Discriminator_loss:0.8775
#
# EPOCH[54] - STEP[40]
# Generator_loss:1.7743
# L1_loss:0.1663
# Discriminator_loss:0.3814
#
# EPOCH[54] - STEP[80]
# Generator_loss:0.9775
# L1_loss:0.1831
# Discriminator_loss:0.7671
#
# EPOCH[54] - STEP[120]
# Generator_loss:1.8000
# L1_loss:0.1906
# Discriminator_loss:0.5886
#
# EPOCH[54] - STEP[160]
# Generator_loss:2.0160
# L1_loss:0.1363
# Discriminator_loss:2.2122
#
# EPOCH[54] - STEP[200]
# Generator_loss:0.8923
# L1_loss:0.1548
# Discriminator_loss:0.6263
#
# ...
# Generator_loss:1.1256
# L1_loss:0.1626
# Discriminator_loss:1.0075
#
# EPOCH[103] - STEP[120]
# Generator_loss:1.8046
# L1_loss:0.1576
# Discriminator_loss:1.0041
# EPOCH[103] - STEP[160]
# Generator_loss:2.2428
# L1_loss:0.1819
# Discriminator_loss:0.4045
#
# EPOCH[103] - STEP[200]
# Generator_loss:1.0097
# L1_loss:0.1463
# Discriminator_loss:1.4211
#
# EPOCH[103] - STEP[240]
# Generator_loss:1.4852
# L1_loss:0.1593
# Discriminator_loss:1.7240
#
# EPOCH[104] - STEP[40]
# Generator_loss:2.4785
# L1_loss:0.1417
# Discriminator_loss:0.5816
#
# EPOCH[104] - STEP[80]
# Generator_loss:1.7145
# L1_loss:0.2010
# Discriminator_loss:0.3722
#
# EPOCH[104] - STEP[120]
# Generator_loss:2.6070
# L1_loss:0.1187
# Discriminator_loss:2.8067
#
# EPOCH[104] - STEP[160]
# Generator_loss:1.0372
# L1_loss:0.1697
# Discriminator_loss:0.6136
#
# EPOCH[104] - STEP[200]
# Generator_loss:0.9918
# L1_loss:0.1534
# Discriminator_loss:1.4494
#
# EPOCH[104] - STEP[240]
# Generator_loss:1.4855
# L1_loss:0.1495
# Discriminator_loss:0.7521
#
# EPOCH[105] - STEP[40]
# Generator_loss:0.8022
# L1_loss:0.1667
# Discriminator_loss:0.7600
#
# EPOCH[105] - STEP[80]
# Generator_loss:0.5862
# L1_loss:0.1398
# Discriminator_loss:1.2819
#
# EPOCH[105] - STEP[120]
# Generator_loss:2.3622
# L1_loss:0.1622
# Discriminator_loss:0.5115
#
# EPOCH[105] - STEP[160]
# Generator_loss:1.2989
# L1_loss:0.1524
# Discriminator_loss:1.1774
#
# EPOCH[105] - STEP[200]
# Generator_loss:3.2157
# L1_loss:0.1577
# Discriminator_loss:1.2081
#
# EPOCH[105] - STEP[240]
# Generator_loss:0.9110
# L1_loss:0.1641
# Discriminator_loss:1.2725
#
# EPOCH[106] - STEP[40]
# Generator_loss:1.5216
# L1_loss:0.1681
# Discriminator_loss:0.4236
#
# EPOCH[106] - STEP[80]
# Generator_loss:1.5062
# L1_loss:0.1551
# Discriminator_loss:1.6248
#
# EPOCH[106] - STEP[120]
# Generator_loss:0.8994
# L1_loss:0.1331
# Discriminator_loss:1.0209
#
# EPOCH[106] - STEP[160]
# Generator_loss:1.0812
# L1_loss:0.1436
# Discriminator_loss:1.2845
#
# EPOCH[106] - STEP[200]
# Generator_loss:1.0695
# L1_loss:0.1652
# Discriminator_loss:2.5731
#
# EPOCH[106] - STEP[240]
# Generator_loss:0.9766
# L1_loss:0.1584
# Discriminator_loss:0.6605
#
# EPOCH[107] - STEP[40]
# Generator_loss:0.6287
# L1_loss:0.1562
# Discriminator_loss:0.9018
#
# EPOCH[107] - STEP[80]
# Generator_loss:1.1125
# L1_loss:0.1638
# Discriminator_loss:1.0218
#
# EPOCH[107] - STEP[120]
# Generator_loss:1.3548
# L1_loss:0.1520
# Discriminator_loss:1.4929
#
# EPOCH[107] - STEP[160]
# Generator_loss:1.8312
# L1_loss:0.1790
# Discriminator_loss:1.1130
#
# EPOCH[107] - STEP[200]
# Generator_loss:1.5735
# L1_loss:0.1862
# Discriminator_loss:0.7160
#
# EPOCH[107] - STEP[240]
# Generator_loss:1.1129
# L1_loss:0.2003
# Discriminator_loss:0.6594
#
# EPOCH[108] - STEP[40]
# Generator_loss:0.6840
# L1_loss:0.1590
# Discriminator_loss:1.0559
#
# EPOCH[108] - STEP[80]
# Generator_loss:0.5328
# L1_loss:0.1608
# Discriminator_loss:1.2700
#
# EPOCH[108] - STEP[120]
# Generator_loss:0.9475
# L1_loss:0.1676
# Discriminator_loss:0.6187
#
# EPOCH[108] - STEP[160]
# Generator_loss:1.9854
# L1_loss:0.1279
# Discriminator_loss:2.1066
#
# EPOCH[108] - STEP[200]
# Generator_loss:1.6193
# L1_loss:0.1837
# Discriminator_loss:0.4090
#
# EPOCH[108] - STEP[240]
# Generator_loss:1.2178
# L1_loss:0.1741
# Discriminator_loss:0.8366
#
# EPOCH[109] - STEP[40]
# Generator_loss:1.2870
# L1_loss:0.1608
# Discriminator_loss:0.8000
#
# EPOCH[109] - STEP[80]
# Generator_loss:1.1676
# L1_loss:0.1444
# Discriminator_loss:1.4295
#
# EPOCH[109] - STEP[120]
# Generator_loss:1.3837
# L1_loss:0.1590
# Discriminator_loss:0.5379
#
# EPOCH[109] - STEP[160]
# Generator_loss:0.6403
# L1_loss:0.1644
# Discriminator_loss:0.9522
#
# EPOCH[109] - STEP[200]
# Generator_loss:1.0355
# L1_loss:0.1409
# Discriminator_loss:1.3968
#
# EPOCH[109] - STEP[240]
# Generator_loss:0.9931
# L1_loss:0.1782
# Discriminator_loss:0.6860
#
# EPOCH[110] - STEP[40]
# Generator_loss:0.5716
# L1_loss:0.1747
# Discriminator_loss:1.0081
#
# EPOCH[110] - STEP[80]
# Generator_loss:0.4667
# L1_loss:0.1521
# Discriminator_loss:1.6339
#
# EPOCH[110] - STEP[120]
# Generator_loss:1.1669
# L1_loss:0.1605
# Discriminator_loss:0.5253
#
# EPOCH[110] - STEP[160]
# Generator_loss:2.1293
# L1_loss:0.1562
# Discriminator_loss:0.3934
#
# EPOCH[110] - STEP[200]
# Generator_loss:1.5218
# L1_loss:0.1391
# Discriminator_loss:1.5293
#
# EPOCH[110] - STEP[240]
# Generator_loss:1.3721
# L1_loss:0.1586
# Discriminator_loss:0.5048
#
# EPOCH[111] - STEP[40]
# Generator_loss:1.5201
# L1_loss:0.1784
# Discriminator_loss:0.4282
#
# EPOCH[111] - STEP[80]
# Generator_loss:0.8967
# L1_loss:0.1515
# Discriminator_loss:0.9994
#
# EPOCH[111] - STEP[120]
# Generator_loss:1.9803
# L1_loss:0.1341
# Discriminator_loss:1.3217
#
# EPOCH[111] - STEP[160]
# Generator_loss:0.8901
# L1_loss:0.1611
# Discriminator_loss:0.7149
#
# EPOCH[111] - STEP[200]
# Generator_loss:1.3216
# L1_loss:0.1760
# Discriminator_loss:0.9338
#
# EPOCH[111] - STEP[240]
# Generator_loss:1.0062
# L1_loss:0.1559
# Discriminator_loss:1.0739
#
# EPOCH[112] - STEP[40]
# Generator_loss:1.2740
# L1_loss:0.1491
# Discriminator_loss:1.3535
#
# EPOCH[112] - STEP[80]
# Generator_loss:1.1385
# L1_loss:0.1598
# Discriminator_loss:0.5223
#
# EPOCH[112] - STEP[120]
# Generator_loss:1.4879
# L1_loss:0.1765
# Discriminator_loss:0.6459
#
# EPOCH[112] - STEP[160]
# Generator_loss:1.7225
# L1_loss:0.1646
# Discriminator_loss:1.1473
# EPOCH[112] - STEP[200]
# Generator_loss:1.9606
# L1_loss:0.1797
# Discriminator_loss:0.2669
#
# EPOCH[112] - STEP[240]
# Generator_loss:1.6189
# L1_loss:0.1603
# Discriminator_loss:0.5184
#
# EPOCH[113] - STEP[40]
# Generator_loss:1.2736
# L1_loss:0.1564
# Discriminator_loss:1.3073
#
# EPOCH[113] - STEP[80]
# Generator_loss:0.5507
# L1_loss:0.1923
# Discriminator_loss:1.0324
#
# EPOCH[113] - STEP[120]
# Generator_loss:1.5972
# L1_loss:0.1766
# Discriminator_loss:0.7107
#
# EPOCH[113] - STEP[160]
# Generator_loss:0.6821
# L1_loss:0.1542
# Discriminator_loss:1.1996
#
# EPOCH[113] - STEP[200]
# Generator_loss:0.9343
# L1_loss:0.1441
# Discriminator_loss:1.4135
#
# EPOCH[113] - STEP[240]
# Generator_loss:2.2358
# L1_loss:0.1654
# Discriminator_loss:1.0512
#
# EPOCH[114] - STEP[40]
# Generator_loss:1.2475
# L1_loss:0.1599
# Discriminator_loss:0.4652
#
# EPOCH[114] - STEP[80]
# Generator_loss:1.3843
# L1_loss:0.1482
# Discriminator_loss:1.1598
#
# EPOCH[114] - STEP[120]
# Generator_loss:0.3889
# L1_loss:0.1460
# Discriminator_loss:1.6878
#
# EPOCH[114] - STEP[160]
# Generator_loss:1.7233
# L1_loss:0.1444
# Discriminator_loss:0.7305
#
# EPOCH[114] - STEP[200]
# Generator_loss:1.0235
# L1_loss:0.1617
# Discriminator_loss:0.5959
#
# EPOCH[114] - STEP[240]
# Generator_loss:0.6178
# L1_loss:0.1641
# Discriminator_loss:1.4059
#
# EPOCH[115] - STEP[40]
# Generator_loss:0.6721
# L1_loss:0.1767
# Discriminator_loss:1.2931
#
# EPOCH[115] - STEP[80]
# Generator_loss:1.0485
# L1_loss:0.1912
# Discriminator_loss:0.5073
#
# EPOCH[115] - STEP[120]
# Generator_loss:1.0846
# L1_loss:0.1441
# Discriminator_loss:1.0494
#
# EPOCH[115] - STEP[160]
# Generator_loss:1.8040
# L1_loss:0.1560
# Discriminator_loss:0.4289
#
# EPOCH[115] - STEP[200]
# Generator_loss:1.7314
# L1_loss:0.1443
# Discriminator_loss:0.7381
#
# EPOCH[115] - STEP[240]
# Generator_loss:0.1572
# L1_loss:0.1866
# Discriminator_loss:3.8036
#
# EPOCH[116] - STEP[40]
# Generator_loss:0.8158
# L1_loss:0.1672
# Discriminator_loss:0.9469
#
# EPOCH[116] - STEP[80]
# Generator_loss:1.6570
# L1_loss:0.1456
# Discriminator_loss:1.8096
#
# EPOCH[116] - STEP[120]
# Generator_loss:2.1216
# L1_loss:0.1914
# Discriminator_loss:0.2786
#
# EPOCH[116] - STEP[160]
# Generator_loss:2.3070
# L1_loss:0.1915
# Discriminator_loss:1.3837
#
# EPOCH[116] - STEP[200]
# Generator_loss:1.6996
# L1_loss:0.1759
# Discriminator_loss:1.1850
#
# EPOCH[116] - STEP[240]
# Generator_loss:1.2431
# L1_loss:0.1398
# Discriminator_loss:0.9066
#
# EPOCH[117] - STEP[40]
# Generator_loss:1.4549
# L1_loss:0.1885
# Discriminator_loss:0.3670
#
# EPOCH[117] - STEP[80]
# Generator_loss:2.0741
# L1_loss:0.1454
# Discriminator_loss:1.7040
#
# EPOCH[117] - STEP[120]
# Generator_loss:0.5949
# L1_loss:0.1974
# Discriminator_loss:0.9197
#
# EPOCH[117] - STEP[160]
# Generator_loss:1.3210
# L1_loss:0.1537
# Discriminator_loss:3.0700
#
# EPOCH[117] - STEP[200]
# Generator_loss:1.0665
# L1_loss:0.1826
# Discriminator_loss:0.6790
#
# EPOCH[117] - STEP[240]
# Generator_loss:1.8386
# L1_loss:0.1671
# Discriminator_loss:0.9603
#
# EPOCH[118] - STEP[40]
# Generator_loss:1.2353
# L1_loss:0.1378
# Discriminator_loss:0.9197
#
# EPOCH[118] - STEP[80]
# Generator_loss:1.8616
# L1_loss:0.1356
# Discriminator_loss:1.1114
#
# EPOCH[118] - STEP[120]
# Generator_loss:0.4274
# L1_loss:0.1643
# Discriminator_loss:1.8490
#
# EPOCH[118] - STEP[160]
# Generator_loss:1.8148
# L1_loss:0.1501
# Discriminator_loss:0.7543
#
# EPOCH[118] - STEP[200]
# Generator_loss:0.8525
# L1_loss:0.1584
# Discriminator_loss:0.6666
#
# EPOCH[118] - STEP[240]
# Generator_loss:1.1473
# L1_loss:0.1637
# Discriminator_loss:0.6710
#
# EPOCH[119] - STEP[40]
# Generator_loss:1.4142
# L1_loss:0.1406
# Discriminator_loss:0.8151
#
# EPOCH[119] - STEP[80]
# Generator_loss:1.0950
# L1_loss:0.1595
# Discriminator_loss:0.6618
#
# EPOCH[119] - STEP[120]
# Generator_loss:1.2570
# L1_loss:0.1551
# Discriminator_loss:1.0805
#
# EPOCH[119] - STEP[160]
# Generator_loss:1.1055
# L1_loss:0.1636
# Discriminator_loss:0.5686
#
# EPOCH[119] - STEP[200]
# Generator_loss:0.6440
# L1_loss:0.1506
# Discriminator_loss:0.9741
#
# EPOCH[119] - STEP[240]
# Generator_loss:1.0043
# L1_loss:0.1880
# Discriminator_loss:0.5880
#
# EPOCH[120] - STEP[40]
# Generator_loss:1.8657
# L1_loss:0.1293
# Discriminator_loss:1.3691
#
# EPOCH[120] - STEP[80]
# Generator_loss:0.8598
# L1_loss:0.1385
# Discriminator_loss:1.2657
#
# EPOCH[120] - STEP[120]
# Generator_loss:1.5542
# L1_loss:0.1739
# Discriminator_loss:1.6341
#
# EPOCH[120] - STEP[160]
# Generator_loss:1.7339
# L1_loss:0.1845
# Discriminator_loss:0.4981
#
# EPOCH[120] - STEP[200]
# Generator_loss:1.4825
# L1_loss:0.1542
# Discriminator_loss:0.4029
#
# EPOCH[120] - STEP[240]
# Generator_loss:2.3927
# L1_loss:0.1461
# Discriminator_loss:1.5553

# %%
test_ind = 0

f = val_path + os.listdir(val_path)[test_ind]
segment_map,road = load_img(f)

pred = generator(tf.expand_dims(segment_map, 0))
pred = denormalize(pred)

plt.figure(figsize=(20,10))
plt.subplot(1,3,1); plt.imshow(denormalize(segment_map))
plt.subplot(1,3,2); plt.imshow(pred[0])
plt.subplot(1,3,3); plt.imshow(denormalize(road))

# %% [markdown]
# epoch를 120번 돌리자 도로의 형태도 보이고 자동차의 형태도 제대로 보이네요.
#
# 결과물을 보면 위에서부터 10번 -> 50번 -> 120번 순으로 cGAN의 결과가 좋아지는 것을 확인할 수 있습니다.

# %% [markdown]
# ---

# %% [markdown]
# ##  회고
#
# - 예전에 했었던 GAN 프로젝트때는 며칠 동안 제대로 된 결과물이 나오기까지 계속해서 네트워크 구조를 조정하고 Hyper parameter들을 여러번 비교하면서 더 좋은 값으로 바꾸는 작업을 했었는데 이번 cGAN의 경우 많은 네트워크 구조의 조정이나 Hyper parameter 값의 변경이 적었음에도 결과물이 금방 그럴듯하게 나왔습니다.<br><br>
# 가장 큰 이유로는 저번에 했었던 GAN의 경우 (32,32)에 작은 사이즈 이미지여서 더 결과물이 제대로 안나왔던것 같습니다.
#
#
# - 이번 cGAN의 경우 결과가 좋게 나와서 GAN 했을때 보다 재미있게 프로젝트를 진행한것 같습니다.  그리고 일반 GAN에서는 안되었던 원하는 이미지를 새로 생성하는 부분으로 할 수 있는 프로젝트가 많은것 같아서 그런 프로젝트를 생각하면서 진행하니 더 좋은 결과가 나왔던것 같네요.
#
#
# - 예를들어, 특정 이미지를 진짜 같이 생성할 수 있으면 위조된 그림을 판별할 때 학습시킬 데이터를 만들 모델로 사용할 수도 있겠네요.
# GAN에 대해서 알면 알수록 많은 분야에서 효율적으로 사용할 수 있는 기술인 것 같습니다. <br>   제가 생각하는 GAN 기술은 앞으로 AI를 활용한 이미지 분야에서 안 좋은 용도로 사용된 시각적 결과를 판별할 수 있는 필수적인 기술인것 같습니다.
